# %%
#LESJ_知財に関する統合報告書大賞_企業別形態素解析出力
# テキストをリスト単位で取り込み、リスト単位で形態素解析
import pandas as pd
import MeCab
import fitz
import re
import sys
sys.path.append('/work_dir') 
import talknize_module_20240909 as tk
import csv

# %%
#形態素解析の前処理
#分析対象データの特性に対応するため、前処理はモジュールではなくコードとして記載
#talknize_module.pyにも標準的な処理も記載し、適宜使い分け可能にする

#----------------------------------------------------------------------
#テキストファイルの各行に記載された文字列を、処理用文字列として整形・リスト化
def text_to_list(file_path):

    # 空のリストを作成
    return_list = []
    try:
        # 指定されたファイルを読み込み、各行をリストに追加
        with open(file_path, 'r') as file:
            # ファイル内の各行をループし、行末の改行や余分な空白を除去してリストに格納
            return_list = [line.strip() for line in file]
    # ファイルが存在しない場合は例外を無視する
    except FileNotFoundError:
        pass
    # リストを返す
    return return_list

#----------------------------------------------------------------------
#形態素解析前のテキストデータ処理（
#形態素解析の前に、無駄な記号やヘッダ・フッタ等の文言をテキストから除外
def pre_tk(text, excl_list):

    replaced_text = text

    #exclusion_list処理前に処理する必要のあるもの
    #【特例処理】除外処理前に、文頭のこれら記号は「箇条書き」とみなし、続く文言を一文として扱う
    replaced_text = re.sub(r'[■□▪▫▲△▶▷▸▹▼▽◆◇●〇]', '。\n', replaced_text)
    #replaced_text = re.sub(r'[〇●◇◆□■▶△▲▽▼▫▪▹▶▸]', '', replaced_text)#上記以外は除去

    exclusion_list = []    
    exclusion_file1 = "userdic/exclusion_phrases1.txt"  # 各企業の除外フレーズを記載したリスト
    exclusion_file2 = "userdic/exclusion_codes.txt"  # その他記号・年月日・URL等を除外するためのリスト
    #exclusion_file3 = "userdic/exclusion_phrases2.txt"  # 各企業の除外フレーズを記載したリスト2（pageinfoから都度取り込み）
#    exclusion_list = text_to_list(exclusion_file1) + text_to_list(exclusion_file2)+ text_to_list(exclusion_file3)
    exclusion_list = excl_list + text_to_list(exclusion_file1) + text_to_list(exclusion_file2)

    for pattern in exclusion_list:
        replaced_text = re.sub(pattern, ' ', replaced_text)

    return replaced_text

# %%
#形態素解析の後処理
#形態素解析結果（tokenリスト）から、ストップワード、特定の条件の文字列等を除外
#import fitz
#import re
from collections import OrderedDict
import re

def post_tk(tokens):
    
    replaced_list = tokens    

    # stopwords（ファイルに格納）を除去
    path_stopwords = "userdic/stopwords.txt"
    stopwords = text_to_list(path_stopwords)
    stopwords = list(OrderedDict.fromkeys(stopwords)) # 元の順序を保持しつつ、重複を除去（# Python 3.7以降）
    replaced_list = [t for t in replaced_list if t not in stopwords]
    
    # ひらがなのみの要素を除去
    kana_re = re.compile("^[ぁ-ゖ]+$")
    replaced_list = [t for t in replaced_list if not kana_re.match(t)]

    # アルファベット1文字のみの要素を除去
    alphabet_re = re.compile("^[a-zA-Z]$")
    replaced_list = [t for t in replaced_list if not alphabet_re.match(t)]

    #特定の形態の数値要素を除去
    number_re = re.compile("^[\d,]+")
    replaced_list = [t for t in replaced_list if not number_re.match(t)]

    
    return replaced_list

# %%
industry = 'temp'
company_name = 'temp'
company_code = 'temp'
doc_name = 'temp'
#analysis_area = 'CEO_Message'
analysis_area = 'R&D'

#open_file='ir/2025/40610_デンカ/denkareport2024_CEO.txt'
open_file='ir/2025/temp/250122研修会「ブランド価値評価とブランディングの推進（集合Zoomウェビナー）」配布資料.txt'
with open(open_file, "r", encoding="utf-8") as file:
    text = file.read()
    #無駄な改行を削除の上で'。'で改行、一文の範囲を明確にする
page_text=[]
#text = re.sub(r'。','。\n', re.sub(r'\n\n+','', text))
text = re.sub(r'。','。\n', text)
page_text.append(text)

print(page_text[0])
# Out:
#
#
# ブランド価値評価とブランディングの推進
#
# 講演資料
#
# インターブランドジャパン 中村正道
#
# ⽇本弁理⼠会 御中
#
# 2025. 1. 22
#
#
#
#
#
# ご依頼の内容：
#
# ・「ブランド」をどう捉え、どのように可視化するか？
#
# ・なぜ可視化が必要なのか？ブランド価値を向上させることで、事業・企業の価値をどう向上させるのか？
#
#
#
#
#
# ご依頼の内容：
#
# ・「ブランド」をどう捉え、どのように可視化するか？
#
# ・なぜ可視化が必要なのか？ブランド価値を向上させることで、事業・企業の価値をどう向上させるのか？
#
#
#
#
#
# 5
#
# Agenda→
#
# ⾃⼰紹介とInterbrandについて→
#
# そもそも「ブランド」とは何か→
#
# ブランド価値評価について→
#
# ブランド強度スコアを活⽤したマネジメント
#
# →
#
# ディスカッション
#
#
#
#
#
# 6
#
# Agenda→
#
# ⾃⼰紹介とInterbrandについて→
#
# そもそも「ブランド」とは何か→
#
# ブランド価値評価について→
#
# ブランド強度スコアを活⽤したマネジメント
#
# →
#
# ディスカッション
#
#
#
#
#
# Omnicomグループ傘下の広告会社で、ブランド/マーケティング・コミュニケーション領域において多岐にわたるプロジェクトに携わり、2005年よりインターブランドに参画し、クライアントサービス＆ソリューション部⾨のディレクターとして、幅広い業種のクライアントとのリレーションシップ構築を推進。
# これまでに、数多くのコーポレートブランド、プロダクトブランド等のブランド戦略・マーケティング戦略を幅広く担当。
# クライアントのビジネス課題解決に向け、戦略構築からクリエイティブ開発までシームレスにブランド戦略プロジェクトをリードする。
# また、Best Japan Brands、顧客体験価値ランキング、「NIKKEI-Interbrand パーパス経営調査」の創設など、ブランドを中核とする企業変⾰の啓蒙活動を推進する。
#
#
# 著書:「ブランディング 」⽇経⽂庫 (⽇本経済新聞出版社/2019年)「ブランディング7つの原則[実践編]」(⽇本経済新聞出版社/2019年/ 共著)「ブランディング7つの原則[改訂版] 」(⽇本経済新聞出版社/2017年/共著）
#
# 中村 正道 （なかむら まさみち）株式会社インターブランドジャパンExecutive Fellow⾃⼰紹介
#
#
#
# About Interbrand
#
# インターブランドのご紹介
#
#
#
#
#
# 1974年にロンドンで創⽴。
# 本社所在地はニューヨーク。
# 11ヵ国にわたる展開を⾏い、グローバルのクロスボーダーでのチーム組成による顧客企業（クライアント）⽀援やグローバルでの最先端事例・知⾒に基づくサービスを提供している
#
# 9
#
#
#
#
#
# 組織概要
#
# 10
#
# Client Services &amp; Solutions
#
# 約20名
#
# Strategy
#
# 約35名
#
# Creative
#
# 約35名
#
# ExperienceActivation
#
# 約10名
#
# 営業窓⼝としてCSSチームがクライアントの課題を把握、最適なセットアップを⾏い、Brand Valuation™をはじめとする先端的な分析⼿法を⽤いる“Strategy”、数多くの受賞歴と⾼い創造性を持つ“Creative”、ブランドを体現するMovesを⾰新的な形で実現化する“”Experience  Activation”が⼀つのチームとなり、ワンストップで最適な問題解決を創造しプロジェクトを推進します。
#
#
#
#
#
#
# Interbrand Thinking &amp; Making 3.0
#
# We areGrowth partner.
#
# 経営コンサルタントとクリエイターとビジネスプロデューサーが⽣み出すシナジーによる
#
# クライアントの成⻑⽀援・変⾰を通じて「次世代の当たり前」を⽣み出す。
# その結果、世界をリードする企業・組織が増え、⽇本が成⻑し、そして社会が豊かになる。
#
#
# 11
#
#
#
#
#
# IEEE 802.11
#
#
#
#
#
# IEEE規格：
#
# Institute of Electrical and Electronics Engineers (⽶国電⼦学会) が定める異なる通信機器同⼠が共通の⼿順で通信できるようにするための決まりごと
#
#
#
#
#
# IEEE 802.11
#
#
#
# 15
#
#
#
#
#
# インターブランドの提供活動
#
# 16
#
# ネーミングの開発
#
# ブランドロゴの開発
#
# 世界観の規定
#
# ブランド価値の評価
#
# ブランドマネジメント⽀援
#
# ブランドエクスペリエンス具現化
#
# 経営へのブランド適応アプローチ開発
#
# 1974Now
#
#
#
#
#
#
#
# 18
#
# 18
#
# iF Design Award 2022
#
# Gamba Osaka
#
# BE THE HEAT, BE THE HEART
#
# Soccer club rebrand
#
#
#
# 19
#
# 19
#
# iF Design Award 2022
#
# Fujitsu
#
# Fujitsu Brand Identity Refresh
#
# Corporate Brand Identity System
#
#
#
# 20
#
# 20
#
# iF Design Award 2022
#
# Matsukiyo
#
# Matsukiyo GO!!
#
# Retail drug store (health and beauty)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# A brand is a living business asset
#
# ブランドとは、常に変化する事業資産である
#
#
#
#
#
# 26
#
#
#
#
#
# 27
#
#
#
#
#
# 28
#
# Marketing Activity
#
# NIKKEI-Interbrand
#
# パーパス経営調査
#
#
#
#  ⽇本経済新聞 朝刊（2022年6⽉10⽇掲載)⽇本経済新聞 朝刊（2022年8⽉31⽇掲載)
#
#
#
#  30
#
# JapanBrandingAwards
#
#
#
#
#
# ⽇本経済新聞 朝刊（2024年6⽉24⽇掲載)
#
# 2025年1⽉23⽇発表！
#
#
#
#
#
# 32
#
# Agenda→
#
# ⾃⼰紹介とInterbrandについて→
#
# そもそも「ブランド」とは何か→
#
# ブランド価値評価について→
#
# ブランド強度スコアを活⽤したマネジメント
#
# →
#
# ディスカッション
#
#
#
# 33
#
# 33
#
# Q：ブランドとは何か？
#
#
#
# 34
#
# 34
#
# Q：ブランドとは何か？
#
#
#
# 35
#
# 35
#
# Q：ブランドとは何か？1) 素敵なロゴと名前2) TVCM3) ⾼級品の証明4) 有名になること5) ⼈が何をするか決める理由のひとつ6) 唯⼀無⼆の競争優位の源泉
#
#
#
# 36
#
# 36
#
# A：ブランドとは
#
# 5) ⼈が何をするか決める 理由のひとつ
#
#
#
# 37
#
# 37
#
# つまり⾏動変容の理由である
#
# A：ブランドとは
#
#
#
# 38
#
# 38
#
# 曖昧なまま、都合よく、⼝々に語られる「ブランディング」
#
#
#
# 39
#
# 39
#
# ⼆つのブランディング
#
#
#
# 40
#
# よくある位置づけ あるべき位置づけ
#
# I R
#
# カスタマーサポート
#
# 営 業
#
# マーケティング
#
# ⼈事・採⽤
#
# 製 造
#
# 研究・開発
#
# ブランド広告&amp;コミュニケーション事業戦略
#
# I R
#
# カスタマーサポート
#
# 営 業
#
# マーケティング
#
# ⼈事・採⽤
#
# 製 造
#
# 研究・開発
#
# 事業戦略ブランド
#
#
#
# 41
#
# １部⾨が担う施策？全社組織で取り組む活動？or
#
#
#
# 42
#
# ブランディングは全社組織を動かす活動である。
#
#
# I R
#
# カスタマーサポート
#
# 営 業
#
# マーケティング
#
# ⼈事・採⽤
#
# 製 造
#
# 研究・開発
#
# 事業戦略ブランド
#
#
#
# 43
#
# ビジネスが成功する可能性を⾼めるにはどのような評判をつくればよいか?
#
# よい評判をさらに⾼めるにはどのようなビジネス/事業活動を⾏えばよいか?
#
# 事業戦略｜｜よいビジネスづくり
#
# ブランド戦略｜｜よい評判づくり
#
#
#
# 44
#
# 44
#
# ブランドが実現する効果ブランドは社員、顧客、投資家・パートナーに影響を与え、経済的な価値を⽣む
#
# Choice  |  選んでもらうPremium  |  ⾼く買ってもらうLoyalty  |  買い続けてもらう顧客
#
# 1
#
# Attract  |  ⼈材を魅きつけるRetain  |  ⼈材を引き留めるMotivate  |  やる気を⾼める社員
#
# 2
#
# Invest  |  投資してもらうCollaborate  |  協業してもらうTrust  |  保証してもらう投資家・パートナー
#
# 3Brand$
#
#
#
# 45
#
#
#
# 46
#
# どのような印象・連想を持ちましたか？
#
#
#
# 47
#
# 47
#
# 製品は、⼯場に商品は、スーパーにブランドは、顧客の頭の中に
#
# 存在する。
#
#
#
#
# 48
#
# ステークホルダーの頭の中に確固たる評判(存在感)を確⽴すること。
#
#
# つまり、「評判」というハンコを押すようなものです。
#
#
# ブランドを創るということは・・・
#
#
#
# 49
#
# 49
#
# “もし、コカ・コーラが災害で全ての⽣産設備を失っても、会社は⽣き残る。
#
#
# しかし、全ての顧客が記憶を失いコカ・コーラに関する全てを忘れてしまえば、会社は倒産する。
# ”
#
#   ーコカ・コーラ社の役員が発したコメント
#
#
#
# 50
#
# ⼝コミ
#
# 売り場
#
# パッケージ
#
# サービス広告
#
# 販促
#
# 店舗
#
# PR
#
# ＢＲＡＮＤ
#
# お客様はブランドをさまざまな接点から知覚する
#
#
#
# 51 51
#
# 社員への浸透・共有社員の態度・⾏動反映タッチポイントでの発信・表現反映
#
# インターナル（社内）エクスターナル（社外）
#
# ブランドとしてのありたい姿
#
# etc.
#
# 世の中のステークホルダーからの認識・理解
#
# サービスWeb
#
# 広告店舗
#
# ソリューション
#
# ブランドのありたい姿が社内で共有され、各タッチポイントを通じてステークホルダーに適切に知覚される
#
# 強いブランドが有する価値の浸透構造と要件
#
# 営業IT
#
# 広報・宣伝販売
#
# R&amp;D
#
# ブランドマネジメント
#
# 企業の約束ステークホルダーの知覚
#
#
#
# 52 52
#
# 社員への浸透・共有社員の態度・⾏動反映タッチポイントでの発信・表現反映
#
# インターナル（社内）エクスターナル（社外）
#
# ブランドとしてのありたい姿
#
# etc.
#
# 世の中のステークホルダーからの認識・理解
#
# サービスWeb
#
# 広告店舗
#
# ソリューション
#
# 活動が部分最適となり、ブランドのありたい姿がステークホルダーに適切に知覚されない
#
# 営業IT
#
# 広報・宣伝販売
#
# R&amp;D
#
# 弱いブランドに共通する問題点
#
# CD
#
# AB
#
# CD
#
# AB
#
# 企業の約束ステークホルダーの知覚
#
#
#
#
#
# 具体的事実の集約⽬に⾒える形に具現化あらゆる活動の拠り所となる考え⽅
#
# ブランドの中核概念
#
# 活動の拠り所になる考え⽅がブランディングの起点となる
#
#
#
#
#
# ブランドプロミス
#
# 顧客が対価を受ける具体的対象商品・サービス
#
# 顧客が対価にたどり着く⼈的接点⼈・⾏動
#
# 顧客が対価にたどり着く空間的接点空間・チャネル
#
# 顧客がブランドを感じるチャネルコミュニケーション
#
# ブランドプロミス
#
# 顧客のインサイトPeopleand Insight
#
# 競合優位性Positioning
#
# 存在意義Purpose
#
# 活動の拠り所になる考え⽅がブランディングの起点となる
#
# あらゆる活動の拠り所となる考え⽅
#
# ブランドの中核概念
#
#
#
#
#
# ブランドの考え⽅を実体化するための４つの視点
#
# Products and Services 製品とサービスPeople and Behaviors 人々と行動
#
# Environments and Channels空間・環境とチャネルCommunications コミュニケーション
#
# ブランドプロミスあらゆる活動の拠り所となる考え⽅
#
# ブランドの中核概念
#
#
#
# 56
#
#
#
# 57
#
# スターバックスのブランドプロミス
#
# ブランドプロミスあらゆる活動の拠り所となる考え⽅
#
# ブランドの中核概念
#
#
#
# 58
#
# “第三の場”の提供
#
#
#
#
#
# Products and Services 製品とサービスPeople and Behaviors ⼈々と⾏動
#
# Communications コミュニケーション
#
# Environments and Channels空間・環境とチャネル
#
# “Third Place”
#
# ブランドの考え⽅を４つの視点で実体化
#
#
#
#
#
# 60
#
# Best Global Brands 2024
#
# Starbucks  15.3 (USD billion)
#
#
#
# 61
#
# ビジネスが成功する可能性を⾼めるにはどのような評判をつくればよいか?
#
# よい評判をさらに⾼めるにはどのようなビジネス/事業活動を⾏えばよいか?
#
# 事業戦略｜｜よいビジネスづくり
#
# ブランド戦略｜｜よい評判づくり
#
#
#
# 62
#
# ブランド戦略と事業戦略･事業活動は⼀体であり、両輪である
#
#
#
# 63
#
# 活動指針に則り顧客ベネフィットを⽣み出す⼀連の事業活動
#
# 確かな評判をつくる⼀貫したブランドの考え⽅・活動指針中核概念
#
# ⼀連の活動が確たる評判となってブランドに蓄積される（ブランドシンボル・ブランド体系）
#
# ブランドの考え⽅
#
# 事業活動
#
# 価値が蓄積される器
#
# 接点
#
# 商品
#
# 店舗
#
# 営業
#
# サービス
#
# 広告・宣伝
#
# etc.
#
# ブランドが育成されるプロセスにおいて、「ブランドの中核概念」が「事業活動で体現」され「価値が蓄積される器」がきちんと構築されていることが重要
#
# ブランドの名称メッセージブランドシンボルブランド体系
#
#
#
# 64
#
# 中核概念ブランドの考え⽅
#
# 事業活動
#
# 価値が蓄積される器
#
# 接点
#
# 商品
#
# 店舗
#
# 営業
#
# サービス
#
# 広告・宣伝
#
# etc.
#
# “第三の場”の提供
#
# ブランドが育成されるプロセスにおいて、「ブランドの中核概念」が「事業活動で体現」され「価値が蓄積される器」がきちんと構築されていることが重要 &lt;Starbucks&gt;
#
# ブランドの名称メッセージブランドシンボルブランド体系
#
#
#
# 65
#
# 65
#
# Agenda→
#
# ⾃⼰紹介とInterbrandについて→
#
# そもそも「ブランド」とは何か→
#
# ブランド価値評価について→
#
# ブランド強度スコアを活⽤したマネジメント
#
# →
#
# ディスカッション
#
#
#
#
#
# ブランド価値算定の仕組み
#
#
#
#
#
# A brand is a living business asset
#
# ブランドとは、常に変化する事業資産である
#
# 再掲
#
#
#
#
#
# 68
#
#
#
#
#
# ブランド価値評価/ Brand Valuation™
#
# •1984年に、世界に先駆けブランド価値を⾦額換算する⼿法 Brand Valuation™を開発•世界の10,000 以上のコーポレート、事業、商品ブランドの価値を評価した実績•財務の視点とマーケティングの視点を併せ持つインターブランド独⾃の⼿法が、世界のデファクトスタンダードとして定着•Brand Valuation™は、2010年ブランド価値算出の⼿法として、世界で初めて国際標準化機構(ISO)からISO 10668 に認定•2016年には、社会的責任投資（SRI)の世界的な株式指標である「ダウジョーンズ・サステナビリティ・インデックス（DJSI）」の選定基準に採⽤
#
#
#
#  70
#
# インターブランドのベスト・ブランド・ランキング
#
# ⾃国以外の海外売上⾼⽐率30％
#
# ■世界のグローバルブランドランキングTop100ブランドを2000年より毎年公表
#
# ■⽇本のグローバルブランド    2009年より公表、2016年からTOP40に
#
# ■⽇本の国内ブランド2011年より公表、2016年からTOP40に
#
# Best Global Brands100
#
# 100BestJapanBrands■⽇本の   ブランドランキング    Top100ブランドを    2020年より公表
#
#
#
#
#
# Best Global Brandsの評価対象ブランド
#
# 71
#
# •主要基盤地域（Home Region）以外での売上⾼⽐率が30%以上あること•北⽶・欧州・アジア地域で相応のプレゼンスがあり，新興国も幅広くカバーして事業展開していること•ブランドの財務的評価を実施するために必要な，各種財務情報が公表されていること•資本コストを織り込んだ「エコノミックプロフィット」が⻑期的にポジティブであること•主要基盤地域のみならず，世界の主要な国々で⼀般に広く認知されていること•ブランドが顧客の購買⾏動に影響を与えていること
#
# Best Global Brands
#
#
#
#
#
# 72
#
#
#
#
#
# Best Japan Brandsの評価対象ブランド
#
# 73
#
# •⽇本発のブランドであること：⽇本の企業によって⽣み出されたコーポレートおよび事業ブランドであること•各種財務情報が公表されていること、または監査済みの財務情報が⼊⼿可能なこと•⽇本で⼀般に認知されていること•資本コストを織り込んだエコノミックプロフィット（経済的利益）が⻑期的にポジティブであること•「Best Global Brands 2023」ランクインブランドは そのブランド価値⾦額を適⽤
#
# Best Japan Brands
#
#
#
#  74
#
# Best Global Brandsにランクインする企業は、マーケットインデックスよりも株価パフォーマンスが⾼くなることが証明されている
#
# 0
#
# 100
#
# 200
#
# 300
#
# 400
#
# 500
#
# 600
#
# 700
#
# 800
#
# 20002021
#
# S&amp;P 500
#
# WORLD INDEX
#
# Source: Interbrand analysis with data sourced from Refinitiv and Best Global Brands  |  Measuring Total Returns (capital gains/losses from share price fluctuations plus the value of dividends received)
#
# Methodology validated by
#
#
#
#
#
# ブランド価値の向上は無形価値を⾼め、企業価値を⾼めるブランドは無形資産の⼀部であり、この価値を⾼めることにより、企業価値を⾼めることができる
#
# 75
#
# ブランド?億円+α
#
# その他の無形価値?億円
#
# ブランド?億円
#
# 有形価値（投下資本）（運転資本＋固定資産）?億円
#
# 企業価値？億円
#
# 有形価値（投下資本）（運転資本＋固定資産）?億円
#
# その他の無形価値?億円
#
# 企業価値？億円+α
#
# 今今後
#
#
#
#
#
# %
#
# 1. 財務分析
#
# 企業が⽣み出す利益の将来予測を⾏う
#
# 2.ブランドの役割
#
# 利益のうちブランドの貢献分を抽出する
#
# 3.ブランド強度
#
# ブランドによる利益の将来の確実性を評価する
#
# ブランド価値
#
# ブランド価値評価 / Brand Valuation™
#
# ✖➗＝
#
#
#
#  77
#
# ブランド価値評価の３つの分析（図解）
#
# 経済的利益を算定どれくらい儲かるか?
#
# 財務分析1
#
# 資本コスト税引後営業利益
#
# エコノミックプロフィットブランドによるエコノミックプロフィットを抽出ブランドがどれくらい儲けに役⽴っているか?
#
# ブランドの役割分析2
#
# ブランド利益
#
# 20242025202620272028〜ブランド価値
#
# 割引率を決定ブランドによる儲けがどれだけ確実か?
#
# ブランドの強度分析3割引現在価値へ
#
# ブランド価値とは、将来の｢ブランドによって⽣まれる経済的価値｣  の｢現在価値｣
#
#
#
#
#
# 財務分析
#
# ブランドの役割分析
#
# ブランド強度分析
#
# ランキングの場合個別プロジェクトの場合
#
# 公表データ及びアナリストの業績予想を⽤いて分析
#
# 業界平均並みの役割指数を適⽤
#
# 公開情報から定性的に分析
#
# 公表データ及び当社提供データを⽤いて分析
#
# 調査結果等から定量・定性的に分析
#
# 調査結果等から定量・定性的に分析
#
# セグメンテーション１ブランド＝１セグメント地域別・事業別セグメントに分けて分析
#
# ブランドがどれくらい将来利益に役⽴つか?
#
# どれくらい儲かるか?
#
# ブランドによる将来利益がどれくらい確実か?
#
# ブランド価値評価
#
# 78
#
# 個別プロジェクトにおいては、定量・定性の調査結果を⽤い、より詳細に分析することで、ブランドの特徴や課題を浮き彫りにする
#
#
#
#  79
#
# インターブランドのブランド価値算定の３ステップ
#
# 財務分析どれくらい儲かるか?Financial Forecast
#
# ブランド価値Brand Value
#
# ステップ 1
#
# ステップ 2
#
# ステップ 3
#
# ブランドの役割分析ブランドが、どれくらい儲けに役⽴っているか?Role of Brand
#
# ブランドによる儲けがどれくらい確実か?ブランドの強度分析(BSS)Brand Strength
#
# ステップ 1｢エコノミックプロフィット｣を将来まで算定
#
# ステップ 2エコノミックプロフィットのうちで、ブランドによる⾦額に振り分ける
#
# ステップ 3ブランド価値として上記を現在価値に割り戻すための割引率としてブランド強度スコア算定を⽤いる
#
# ■ブランドの価値算定は、１から３までステップを重ねて算定される
#
#
#
#  80
#
#   財務分析
#
# Year 1Year 2Year 3Year 4Year 5
#
# 売上⾼
#
# 営業費⽤
#
# 法⼈税
#
# 税引後営業利益
#
# 資本コスト(*)
#
# 経済的価値エコノミックプロフィット
#
# アナリスト予想値Interbrand 前提
#
# $100.0$200.0$300.0$400.0$500.0
#
# $25.0$50.0$75.0$100.0$125.0$22.5$45.0$67.5$90.0$112.5
#
# $52.5$105.0$157.5$210.0$262.5
#
# $2.4$3.2$4.8$6.4$8.0
#
# $50.1$101.8$152.7$203.6$254.5
#
# 例⽰説明
#
# (*) 資本コスト＝投下資本（運転資本＋有形固定資産）×加重平均資本コスト（WACC）
#
# ■ アナリスト予想値は将来期間が限定的なため、それ以上の年度はインターブランドで前提を設定■ 経済的価値（エコノミックプロフィット）の現在価値割り戻し前の⾦額を将来5ヵ年作成する
#
#
#
# Conﬁden8al - Not for Public Consump8on or Distribu8on81
#
# インターブランドのブランド価値算定の３ステップ
#
# 財務分析どれくらい儲かるか?Financial Forecast
#
# ブランド価値Brand Value
#
# ステップ 1｢エコノミックプロフィット｣を将来まで算定
#
# ステップ 2エコノミックプロフィットのうちで、ブランドによる⾦額に振り分ける
#
# ステップ 3ブランド価値として上記を現在価値に割り戻すための割引率としてブランド強度スコア算定を⽤いる
#
# ステップ 1
#
# ステップ 2
#
# ステップ 3
#
# ブランドの役割分析ブランドが、どれくらい儲けに役⽴っているか?Role of Brand
#
# ブランドによる儲けがどれくらい確実か?ブランドの強度分析(BSS)Brand Strength
#
# ■ブランドの価値算定は、１から３までステップを重ねて算定される
#
#
#
#  82
#
#  ブランド役割分析
#
# 低⾼ブランドの役割
#
# Very LowLowMediumHighVery High0255075100
#
# 機能的Functional情緒的Emotional
#
# 頭で考えるThinkこころで感じるFeel
#
# 事実Fact知覚Perception
#
# 単純Simple複雑Complicated
#
# 可視Visible不可視Invisible
#
# 82
#
# ■ 顧客調査にブランド役割分析を⽬的とした“購買要因”の設問を設定し、次の視点でみてブランドの役割の強弱を判断する■ 購買要因ごと割り当てたブランドの役割を積算して、そのブランドの役割指数を算定する
#
#
#
# Conﬁden8al - Not for Public Consump8on or Distribu8on83
#
#  ブランド役割分析
#
# Role  ofBrand30%
#
# ブランド価格機能品質使いやすさ⼤きさ性能・・・
#
# 顧客の購買要因購買要因にしめるブランドの役割
#
# 例⽰説明
#
# ■ ブランドが「顧客の選択⾏動」に対して与える影響の度合いを数値化したものが「ブランドの役割」
#
#
#
#  84
#
#  ブランド役割分析
#
# 業界別ブランドの役割（平均値）
#
# より機能的に購買/選択が⽣じるより情緒的に購買/選択が⽣じる
#
# ■ インターブランドは、Best Global Brandsの対象業界において ブランドが｢選択｣に与える影響を調査分析し、業界別ブランドの役割を算定している
#
# 宝飾品外⾷⽇⽤品⼩売店⾦融エネルギー
#
# イメージ
#
#
#
#  85
#
# インターブランドのブランド価値算定の３ステップ
#
# 財務分析どれくらい儲かるか?Financial Forecast
#
# ブランド価値Brand Value
#
# ステップ 1
#
# ステップ 2
#
# ステップ 3
#
# ブランドの役割分析ブランドが、どれくらい儲けに役⽴っているか?Role of Brand
#
# ブランドによる儲けがどれくらい確実か?ブランドの強度分析(BSS)Brand Strength
#
# ステップ 1｢エコノミックプロフィット｣を将来まで算定
#
# ステップ 2エコノミックプロフィットのうちで、ブランドによる⾦額に振り分ける
#
# ステップ 3ブランド価値として上記を現在価値に割り戻すための割引率としてブランド強度スコア算定を⽤いる
#
# ■ ブランドの価値算定は、１から３までステップを重ねて算定される
#
#
#
# 86
#
# ブランディングは全社組織を動かす活動である。
#
#
# I R
#
# カスタマーサポート
#
# 営 業
#
# マーケティング
#
# ⼈事・採⽤
#
# 製 造
#
# 研究・開発
#
# 事業戦略ブランド
#
# 再掲
#
#
#
#  87
#
#   ブランド強度分析
#
# LeadershipEngagementRelevance社内指標社外指標
#
# Direction / 志向⼒ブランドの⽬指す姿と、それをどのように実現していくかが明確であり、それを実⾏に導く⽂化と価値観が定義されているかAlignment / 結束⼒組織全体が同じ⽅向に向かい、その実現に全⼒を尽くし、事業全体を通じてそれを実⾏する仕組みを備えているかEmpathy / 共感⼒組織として顧客や他のステークホルダーの声を積極的に聞き、その進化するニーズ・想い・欲求を先んじて予測しそれに応える能⼒を備えているかAgility / 俊敏⼒組織としてビジネス機会や課題に対応し期待を超え続けるため迅速に動くことができるか
#
# Distinctiveness / 独⾃性特徴的なブランド体験を提供し際⽴つものとして既存/潜在顧客から認識され記憶されているか
#
# Coherence / 整合性あらゆる顧客接点でのブランド体験において、⼀貫性のあるブランドストーリーや世界観が感じられるかParticipation / 共創性 顧客やパートナーを巻き込み対話を⽣み、参加や協働を促すことができているか
#
# Presence / 存在感既存・潜在顧客を含む関連するステークホルダーの間で好意的に語られ広く知られており、そのカテゴリーにおいて容易に想起されるものとなっているかTrust / 信⽤度顧客の⾼い期待に応え、誠実に、顧客⽬線で⾏動していると思われているか
#
# Affinity / 愛着度ブランドが提供する機能的・情緒的価値や価値観の共有により、顧客が絆を感じてくれているか
#
# 強く対応⼒のあるブランドを構築する企業と顧客との相互の関係を形作る顧客との絆を強化しロイヤルティを⽣み出す
#
# ■ ブランド強度分析は４つの社内指標と６つの社外指標の計10指標
#
#
#
#  88
#
#   ブランド強度分析：ブランド強度の要素のスコア換算
#
# ■ 各項⽬は競合他社との相対的な評価によって決まるため、⾃社の活動が素晴らしくとも、競合がそれを上回る場合は、スコアが減少する可能性もある
#
# 競合するブランドと⽐較して平均的な評価業界を超えてグローバル・トップレベルの評価
#
# ブランドの価値を毀損するレベル
#
# Direction
#
# 志向⼒Alignment
#
# 結束⼒Empathy
#
# 共感⼒Agility
#
# 俊敏⼒Distinctiveness独⾃性
#
# Coherence
#
# 整合性Participation
#
# 共創性Presence
#
# 存在感Trust
#
# 信⽤度Affinity
#
# 愛着度
#
# 各スコアの合計＝ブランド強度スコア
#
# ブランド強度に課題の多い企業平均的なブランド強度グローバルでトップレベルのブランド強度
#
# ブランド強度スコアが⾼いということは将来に亘ってブランド価値が毀損する「可能性が低い」ということ
#
#
#
#  89
#
#   ブランド強度分析
#
# 理想ブランドであれば…
#
# Direction
#
# 志向⼒Alignment
#
# 結束⼒Empathy
#
# 共感⼒Agility
#
# 俊敏⼒Distinctiveness
#
# 独⾃性Coherence
#
# 整合性Participation
#
# 共創性Presence
#
# 存在感Trust
#
# 信⽤度Affinity
#
# 愛着度
#
# 100
#
# 10
#
# 10
#
# 10
#
# 10
#
# 10
#
# 10
#
# 10
#
# 10
#
# 10
#
# 10
#
# ブランドの⽬指す姿と、それをどう実現するかが明確か？
#
# 組織全体が同じ⽅向に向かい、事業全体を通じて⽬指す姿を実現する仕組みがあるか？
#
# 顧客の声を積極的に聞き、その変化するニーズを予測できるか？
#
# 顧客の期待を超え続けるため迅速かつ柔軟に動くことができるか？
#
# 特徴的なブランドの体験を提供し、際⽴つもとのして認識されているか？
#
# あらゆる顧客接点でのブランド体験に⼀貫性のあるブランドストーリーが感じられるか？
#
# 顧客を巻き込み、対話を⽣み、参加を促すようなブランド体験ができているか？
#
# オピニオンリーダーや既存・潜在顧客に好意的に広く知られ、影響⼒を発揮しているか？
#
# 顧客の⾼い期待に応え、誠実に、顧客⽬線で⾏動していると思われているか？
#
# ブランドが提供する機能的・情緒的価値により顧客が絆を感じてくれているか？
#
# •ブランド強度が⾼いほど、将来のブランドに関わる信頼度 は⾼まるため、将来に亘って⽀払うコスト（＝割引率）は減少する割引率は右図のような逆Sカーブの形をとる
#
# 総合得点
#
# 割引率の考え⽅（逆Sカーブ）
#
# ブランド強度スコア（総合得点）
#
# 0102030405060708090 100
#
# 割引率
#
# 低
#
# ⾼
#
# 弱強
#
# ブランド⼒がない･弱い
#
# ブランドが確⽴されている
#
# ■ ブランド強度分析では、ブランド強度スコアの総合点から割引率を算定している
#
#
#
# 90
#
# 90
#
# Agenda→
#
# ⾃⼰紹介とInterbrandについて→
#
# そもそも「ブランド」とは何か→
#
# ブランド価値評価について→
#
# ブランド強度スコアを活⽤したマネジメント
#
# →
#
# ディスカッション
#
#
#
#
#
# 財務分析
#
# ブランドの役割分析
#
# ブランド強度分析
#
# ランキングの場合個別プロジェクトの場合
#
# 公表データ及びアナリストの業績予想を⽤いて分析
#
# 業界平均並みの役割指数を適⽤
#
# 公開情報から定性的に分析
#
# 公表データ及び当社提供データを⽤いて分析
#
# 調査結果等から定量・定性的に分析
#
# 調査結果等から定量・定性的に分析
#
# セグメンテーション１ブランド＝１セグメント地域別・事業別セグメントに分けて分析
#
# ブランドがどれくらい将来利益に役⽴つか?
#
# どれくらい儲かるか?
#
# ブランドによる将来利益がどれくらい確実か?
#
# ブランド価値評価
#
# 91
#
# 個別プロジェクトにおいては、定量・定性の調査結果を⽤い、より詳細に分析することで、ブランドの特徴や課題を浮き彫りにする
#
#
#
#  92
#
# 全社の成⻑戦略に「ブランド」を位置付け中期経営計画で指標化する
#
#
#
#
#
# 味の素株式会社中期経営計画（2017年2⽉17⽇発表）
#
# 味の素は、前中期経営計画で「2020年ブランド価値⽬標=1,500USD mil.」を掲げ、コーポレートブランド価値を財務・⾮財務の統合価値に位置付けている
#
#
#
#
#
# キリングループは、中期経営計画で、⾮財務⽬標の重要成果指標として、「2021年度ブランド価値⽬標=2,200 USD mil.」を掲げているキリンホールディングス株式会社中期経営計画（2019年2⽉14⽇発表）
#
# 中期経営計画重要成果指標
#
# ⻑期⾮財務⽬標CSVパーパス
#
#
#
#
#
# 2019年4⽉12⽇ヤマハ株式会社ニュースリリースヤマハグループは、中期経営計画で、⾮財務⽬標として「2021年度ブランド価値⽬標=1.3倍」を掲げている
#
#
#
# 96© 2022  Interbrand Japan Inc. 96
#
# 事例：Ajinomoto
#
#
#
# 97
#
#
#
# 98
#
# LeadershipEngagementRelevance
#
# 社内指標社外指標
#
# Direction / 志向⼒ブランドの⽬指す姿と、それをどのように実現していくかが明確であり、それを実⾏に導く⽂化と価値観が定義されているかAlignment/ 結束⼒組織全体が同じ⽅向に向かい、その実現に全⼒を尽くし、事業全体を通じてそれを実⾏する仕組みを備えているかEmpathy / 共感⼒組織として顧客や他のステークホルダーの声を積極的に聞き、その進化するニーズ・想い・欲求を先んじて予測し、それに応える能⼒を備えているかAgility / 俊敏⼒組織としてビジネス機会や課題に対応し、期待を超え続けるため迅速に動くことができるか
#
# Distinctiveness / 独⾃性特徴的なブランド体験を提供し、際⽴つものとして既存/潜在顧客から認識され記憶されているか
#
# Coherence / 整合性あらゆる顧客接点でのブランド体験において、⼀貫性のあるブランドストーリーや世界観が感じられるかParticipation/ 共創性 顧客やパートナーを巻き込み、対話を⽣み、参加や協働を促すことができているか
#
# Presence / 存在感既存・潜在顧客を含む関連するステークホルダーの間で好意的に語られ、広く知られており、そのカテゴリーにおいて容易に想起されるものとなっているかTrust / 信⽤度顧客の⾼い期待に応え、誠実に、顧客⽬線で⾏動していると思われているか
#
# Affinity / 愛着度ブランドが提供する機能的・情緒的価値や価値観の共有により、顧客が絆を感じてくれているか
#
# 強く対応⼒のあるブランドを構築する企業と顧客との相互の関係を形作る顧客との絆を強化しロイヤルティを⽣み出す
#
# 2016年ブランディングの進捗を「ブランド強度」の視点で測定する仕組みを導⼊13ヶ国で社内・社外のコーポレートブランド調査を実施し、ブランド強度スコアを算出した上で、課題を抽出
#
#
#
#
#
# ｢ブランドの⽬指す姿｣（パーパス）を掲げ、⽣活者の課題を解決し、共感を⽣むパワーの測定指標ーこのスコアが競合と⽐較して相対的に⾼ければ、中⻑期的に価値の⾼い安定したブランドとみなされるー
#
# 企業の⽬指す⽅向性が、納得性を持ってしっかりと⽰されているか？ビジネス機会や、課題の変化に対して、俊敏に動く、体制が整っているか？
#
# 顧客の声を聴き、ニーズや市場の変化を予測する⼒があるか？
#
# Direction
#
# 志向⼒
#
# Empathy
#
# 共感⼒
#
# ブランドの⽬指す姿
#
# Coherence
#
# 整合性
#
# Distinctiveness
#
# 独⾃性
#
# Participation
#
# 共創性Trust
#
# 信⽤度Agility
#
# 俊敏⼒
#
# Affinity
#
# 愛着度
#
# Presence
#
# 存在感
#
# 特徴的なブランド体験を⼀貫性をもって提供しているか？顧客の期待にこたえ、誠実に⾏動していると思われているか？
#
# 企業が提供する、情緒的・機能的価値により、顧客が絆を感じてくれているか？
#
# 社内のブランド構築｢ブランドの⽬指す姿｣の実践顧客とのブランド共創（パーパスの社内理解）（パーパスの実践）（パーパスの発信・共感）
#
# ■施策：企業広告・PR活動・HP発信など■施策：商品・販促・イベント・キャンペーンなど■施策：従業員啓発・意識化・⾃分事化
#
# 従業員が同じ⽅向に向かい、事業を通じて実現する仕組みが整っているか？
#
# マスメディア・ソーシャルメディアの双⽅で、好意的に語られ、影響⼒を発揮しているか？
#
# 顧客との関係性を構築するブランド体験を提供できているか？
#
# Leadership
#
# 特徴的なブランド体験を提供し、既存/潜在顧客から認知・記憶されているか？
#
# Alignment
#
# 結束⼒
#
# EngagementRelevance
#
# ブランド強度スコアにもとづくパーパスブランディング
#
# 99
#
# 強く対応⼒のあるブランドが構築されているか？企業と顧客との相互の関係が形作られているか？顧客との絆を強化しロイヤルティが⽣み出されているか？
#
# 認識されるブランドの姿
#
#
#
# 100
#
# BSS評価モデルによりブランドの浸透状況を把握する
#
# 社内のブランド構築「ブランドの⽬指す姿」の実践顧客とのブランド共創（ブランドの社内理解）（ブランドの実践）（ブランドの発信・共感）
#
# ■施策：企業広告・PR活動・HP発信など■施策：商品・販促・イベント・キャンペーンなど■施策：従業員啓発・意識化・⾃分事化
#
# LeadershipEngagementRelevance
#
# Direction
#
# 志向⼒
#
# Alignment結束⼒Empathy
#
# 共感⼒
#
# Agility
#
# 俊敏⼒
#
# Coherence
#
# 整合性
#
# Distinctiveness独⾃性Presence
#
# 存在感
#
# Trust
#
# 信⽤度
#
# Affinity
#
# 愛着度
#
# Participation共創性
#
# 競合A
#
# 競合B
#
# 競合C
#
# ⾼低4.0404.5455.0505.5556.06010点満点※表中のセルの⾊づけ：
#
# 社員調査顧客調査
#
# イメージ
#
#
#
# 101
#
# ブランド価値（⾦額）ブランドの役割指数【ブランドの貢献度）
#
# セグメント別のブランド価値評価からブランドの現状を定量的に把握する概念説明
#
# HigherLower
#
# %
#
# より効果的な実効性を鑑み、事業セグメント別にブランド価値評価を実施する
#
# 〇百万ドル
#
# 〇百万ドル
#
# 〇百万ドル
#
# 〇百万ドル
#
# 競合1競合2競合3競合4競合5
#
# 699百万ドル
#
# 営業
#
# インベストメントマネジメント
#
# ホールセール
#
# その他
#
#
#
# 102
#
# ブランド強度スコアを把握しブランド価値向上の課題を抽出、アクションを導出する
#
# 4.0
#
# 5.0
#
# 5.0
#
# 5.0
#
# 6.0
#
# 7.2
#
# 8.1
#
# 02468
#
# 5.7
#
# 5.7
#
# 3.8
#
# アクション項⽬
#
# 社内向けブランディング
#
# 社外向けブランディング
#
# 競合平均: 5.5
#
# 独⾃性
#
# 共創性
#
# 存在感
#
# 愛着度
#
# 例⽰説明
#
# 社内評価
#
# 社外評価
#
# Direction
#
# 志向⼒Alignment
#
# 結束⼒Empathy
#
# 共感⼒Agility
#
# 俊敏⼒Distinctiveness
#
# 独⾃性Coherence
#
# 整合性Participation
#
# 共創性Presence
#
# 存在感Trust
#
# 信⽤度Affinity
#
# 愛着度
#
# 志向⼒
#
# ブランド強度分析
#
#
#
#
#
# 2017年にAGB(Ajinomoto group Global Brand)を導⼊した
#
# 103
#
# 旧コーポレートブランド味の素グループグローバルブランド(AGB)
#
# 世界の⽣活者が“⾔語を超えて”味の素グループの象徴として認知できるよう新しいグローバルブランドを導⼊した
#
#
#
#
#
# パーパス具現化のための6つの「貢献価値」で商品・サービスの役割を設定
#
# 104
#
# 企業(コーポレートブランド)
#
# 貢献価値
#
# アミノサイエンスで⼈・社会・地球のWell-beingに貢献する
#
# 製品(プロダクトブランド)
#
# 6つの貢献価値を実現するために、主⼒となる商品・サービスの役割を設定
#
# 調理つくりだす歓び絆⼈と交わる歓び栄養カラダが満ちる歓び体調カラダが整う歓び前を向く歓び時間解放される歓び
#
# おいしさ健康によい安⼼・安全環境に配慮
#
# リラクセーション
#
#
#
#
#
# 2020年から「ASVの⾃分ごと化」向上の施策に取り組み、年々、進化させている
#
# 105
#
# (出所)味の素株式会社HP
#
# グローバルな健康課題である⾷塩過剰摂取の解決への取組み
#
# “おいしさ”や”時短調理”を実現する「スチーミー」の開発秘話
#
#
#
#
#
# ブランドコミュニケーション部⾨のKPIとして「ブランド強度スコア(BSS)」を活⽤
#
# 106
#
# •毎年開催される約10か国のブランド・コミュニケーション担当者が集まる「ASV &amp; Brand Communication Conference」において各国のブランド強度スコアを共有している•拠点ごとにブランド強度上の課題を探り、アクションプランを設定し実施、成果を報告している•ブランド強度指標と紐づけるフレームは本社側では⽤意せず各拠点に委ねている•先進事例を紹介した上でワークショップを実施することもある
#
#
#
# 107 (出所)「IR DAY CEOメッセージ味の素グループのASV経営パーパスドリブン組織への変革」(2021年3月23日)
#
# 2021年〜IR情報でもブランド強度スコアKPIを発信しブランディングの取り組みを説明
#
#
#
# 108
#
# 2020〜2022年：2030年⽬指す姿で“志”を追加。
# 統合報告書は「ASVレポート」にASV経営をさらに推し進めつつ、理念はアップデートしていく
#
# 2022ASVレポートより抜粋
#
#
#
# 109
#
# 2023年：新たな中計でもブランド価値を未財務指標の⼀つとして設定している
#
# 中期ASV経営2030ロードマップより抜粋
#
#
#
# 110
#
#
#
#
#
# ブランド価値の⽬標の達成は役員報酬にも紐づいている
#
# 111
#
# (出所)2023年統合報告書より抜粋
#
#
#
# 112
#
# 継続的なブランディングによりブランド価値は10年で2倍になった
#
# 650 718 684 650 711 778 852 780
#
# 926
#
# 1,208
#
# 1,391
#
# 0
#
# 200
#
# 400
#
# 600
#
# 800
#
# 1,000
#
# 1,200
#
# 1,400
#
# 1,600
#
# 20132014201520162017201820192020202120222023
#
# (単位:百万ドル)
#
# (年)
#
# 2.1倍
#
# Ajinomotoのブランド価値
#
# (出所)Best Japan Brandsランキングより
#
# 2014年ASVを中計で表明
#
# 2016年ブランド強度スコア導⼊
#
# 2017年ブランドロゴ世界統⼀/体系整理
#
# ブランド価値⾦額を中計で⽬標として掲載
#
# 2020年2030年⽬指す姿で“志”を追加
#
# 2021年統合報告書をASVレポートに改称
#
# 2023年“志”の進化と2030ロードマップ策定
#
# ブランディングの進化と⼀貫性ある活動の継続
#
# 14-16中計17-19中計20-22中計⻄井社⻑藤江社⻑
#
#
#
# 113
#
# ブランド価値の向上は企業価値の増⼤と呼応している
#
# 650 718 684 650 711 778 852 780
#
# 926
#
# 1,208
#
# 1,391
#
# 1,625
#
# 0
#
# 5,000
#
# 10,000
#
# 15,000
#
# 20,000
#
# 25,000
#
# 30,000
#
# 35,000
#
# 0
#
# 200
#
# 400
#
# 600
#
# 800
#
# 1,000
#
# 1,200
#
# 1,400
#
# 1,600
#
# 1,800
#
# 201320142015201620172018201920202021202220232024
#
# ブランド価値(単位:百万ドル)
#
# (年)
#
# Ajinomotoのブランド価値同年度末企業価値(単位:億円)
#
# (出所)Best Japan Brandsランキングより
#
# 2014年ASVを中計で表明
#
# 2016年ブランド強度スコア導⼊
#
# 2017年ブランドロゴ世界統⼀/体系整理
#
# ブランド価値⾦額を中計で⽬標として掲載
#
# 2020年2030年⽬指す姿で“志”を追加
#
# 2021年統合報告書をASVレポートに改称
#
# 2023年“志”の進化と2030ロードマップ策定
#
# ブランディングの進化と⼀貫性ある活動の継続
#
# 14-16中計17-19中計20-22中計⻄井社⻑藤江社⻑
#
#
#
# 114
#
# ブランド価値の向上は営業利益の増⼤と呼応している
#
# 650 718 684 650 711 778 852 780
#
# 926
#
# 1,208
#
# 1,391
#
# 1,625
#
# 0
#
# 200
#
# 400
#
# 600
#
# 800
#
# 1,000
#
# 1,200
#
# 1,400
#
# 1,600
#
# 0
#
# 200
#
# 400
#
# 600
#
# 800
#
# 1,000
#
# 1,200
#
# 1,400
#
# 1,600
#
# 1,800
#
# 201320142015201620172018201920202021202220232024
#
# ブランド価値(単位:百万ドル)
#
# (年)
#
# Ajinomotoのブランド価値同年度末営業利益(単位:億円)
#
# (出所)Best Japan Brandsランキングより
#
# 2014年ASVを中計で表明
#
# 2016年ブランド強度スコア導⼊
#
# 2017年ブランドロゴ世界統⼀/体系整理
#
# ブランド価値⾦額を中計で⽬標として掲載
#
# 2020年2030年⽬指す姿で“志”を追加
#
# 2021年統合報告書をASVレポートに改称
#
# 2023年“志”の進化と2030ロードマップ策定
#
# ブランディングの進化と⼀貫性ある活動の継続
#
# 14-16中計17-19中計20-22中計⻄井社⻑藤江社⻑
#
#
#
# 115
#
# +30%1,208 $m
#
#
#
# 116
#
# +30%1,208 $m
#
#
#
#
#
# 本⽇、お伝えしたかったこと
#
# üブランディングとは、全社組織を動かす活動であるü強いブランドは、企業側の意図が、社員の活動（＝ビジネスの実体）を通じて、お客さまの知覚を形成しているüブランド戦略と事業戦略･事業活動は⼀体であり、両輪であるüブランド価値の向上は無形価値を⾼め、企業価値を⾼めるü「ブランド強度(BSS)」を全社の事業活動のKPIに活⽤するマネジメントで、企業価値を⾼める
#
#
#
# 118
#
# 実務担当者向けの⼿引書「ブランディング」(⽇経⽂庫)2019年12⽉13⽇ 刊⾏
#
#
#
#
#
# 119
#
# Agenda→
#
# ⾃⼰紹介とInterbrandについて→
#
# そもそも「ブランド」とは何か→
#
# ブランド価値評価について→
#
# ブランド強度スコアを活⽤したマネジメント
#
# →
#
# ディスカッション
#
#
#
#
#
# Q &amp; A

# %%
eliminate_list=[]
#ページインデックス付きで、形態素解析結果をページ単位で格納
tokenized_page_text = [(index, post_tk(tk.mecab_tokenizer(pre_tk(item, eliminate_list))))for index, item in enumerate(page_text)]

# %%
#抽出ページ単位の形態素リスト
Extracted_tokenized_page_text = [(index, sublist) for index, sublist in tokenized_page_text]
#該当ページのインデックスリスト
Extracted_tokenized_page_index = [index for index, sublist in tokenized_page_text]
#形態素解析前の抽出ページ単位テキスト
Extracted_page_text = [page_text[0] ]

# %%
#以降、Wordlist/WordcloudとCentrality,Network図作成
from collections import Counter
import pandas as pd
import itertools
import datetime

# %%
#ファイル出力時に使用する年月日文字列の取得（全処理共通）
# 現在の日付と時刻を取得
now = datetime.datetime.now()
# 年月日と時刻の文字列を生成
date_time_string = now.strftime("%Y%m%d-%H%M%S")

# %%
#Word_listの作成
#抽出されたページの形態素（サブリスト）を一つのリストにまとめる
Merged_Extracted_tokenized_list = [item for _, sublist in Extracted_tokenized_page_text for item in sublist]
#Merged_Extracted_tokenized_list = page_text
#print(Merged_Extracted_tokenized_list)
#辞書形式で単語をカウント
counter = Counter(Merged_Extracted_tokenized_list)

# 単語、件数をDataFrameに格納
count_df = pd.DataFrame(list(counter.items()), columns=['単語', '件数'])
# DataFrameを件数でソート
count_df = count_df.sort_values(by='件数', ascending=False)

# 新しい列を追加
count_df.insert(0, '業種', industry)
count_df.insert(1, 'コード', company_code)
count_df.insert(2, '企業名', company_name)
count_df.insert(3, '分析範囲', analysis_area)
# 結果をCSVファイルに出力
file_name = f"output/{company_code}_{company_name}_{date_time_string}_Word_list.csv"
count_df.to_csv(file_name, encoding="utf_8_sig", index=False)

# %%
#抽出単語によるワードクラウド作成
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 日本語フォントのパスを指定
jp_font_path = '/usr/share/fonts/opentype/ipaexfont-gothic/ipaexg.ttf'

# ワードクラウドのフォーマット指定
wordcloud = WordCloud(width=800, height=400, background_color='white',font_path=jp_font_path)
# 単語とその頻度を辞書形式に変換
word_freq = {word: freq for word, freq in zip(count_df['単語'], count_df['件数'])}
# ワードクラウドの生成
wordcloud.generate_from_frequencies(word_freq)

# プロット
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# 結果をpngファイルに出力
file_name_wordcloud=f'output/{company_code}_{company_name}_{date_time_string}_WordCloud.png'
wordcloud.to_file(file_name_wordcloud)

# %%
#tf-idf用に、ファイル名、企業名、トークンを出力

# データフレームの作成：pdfファイル名とトークンを格納
#df_token = pd.DataFrame({"company_name": company_name, "doc_name": doc_name, "token": [Merged_Extracted_tokenized_list]})

#file_name_token=f'output/{company_code}_{company_name}_{date_time_string}_Token.csv'
#df_token.to_csv(file_name_token, encoding="utf_8_sig", index=False)

# %%
#以降、共起分析
#Extracted_page_text（抽出ページ単位のリスト）を、要素一つのリストに集約
Merged_Extracted_page_text = "\n\n".join(Extracted_page_text)
#print(Merged_Extracted_page_text)

#前処理したテキストを準備
Processed_Merged_Extracted_page_text = pre_tk(Merged_Extracted_page_text, eliminate_list)
#print(Processed_Merged_Extracted_page_text)

#集約・前処理したテキストを「。」で区切り、形態素解析（共起分析用）
sentences = [post_tk(tk.mecab_tokenizer(sentence)) for sentence in re.split("。", Processed_Merged_Extracted_page_text)]
#print(sentences)

# %%
#各文中の、形態素組み合わせを作る
sentences_combs = [list(itertools.combinations(sentence,2)) for sentence in sentences]
#print(sentences_combs[0])

#組み合わせた2つの形態素の並びをソート
words_combs = [[tuple(sorted(words)) for words in sentence] for sentence in sentences_combs]
#print(words_combs[0][:30])
target_combs = []
for words_comb in words_combs:
    target_combs.extend(words_comb)
ct = Counter(target_combs)
#print(ct)
df = pd.DataFrame([{"1番目" : i[0][0], "2番目": i[0][1], "count":i[1]} for i in ct.most_common()])

#ファイル出力
file_name_comb = f"output/{company_code}_{company_name}_{date_time_string}_Co_Occurrence.csv"
df.to_csv(file_name_comb, encoding="utf_8_sig", index=False)

# %%
#df.head(30)

# %%
#ネットワーク分析の下準備
import networkx as nx
from networkx.algorithms.community import girvan_newman
import network_plot_module as npm
import json

#########################################################
# 分析対象とする共起単語の組み合わせ数（ノード数）を指定
analyzed_links = 350
limited_df = df.head(analyzed_links)
#########################################################
# DataFrameからネットワークを作成
G = nx.from_pandas_edgelist(limited_df, '1番目', '2番目', ['count'])

# %%
#print(G)
#limited_df.head(30)

# %%
# 各ノードの中心性を計算
try:
    degree_centrality = nx.degree_centrality(G)
except:
    degree_centrality = {node: '' for node in G.nodes()}
    
try:
    betweenness_centrality = nx.betweenness_centrality(G)
except:
    betweenness_centrality = {node: '' for node in G.nodes()}

try:
    closeness_centrality = nx.closeness_centrality(G)
except:
    closeness_centrality = {node: '' for node in G.nodes()}

try:
    eigenvector_centrality = nx.eigenvector_centrality(G)
except:
    eigenvector_centrality = {node: '' for node in G.nodes()}

try:
    katz_centrality = nx.katz_centrality(G)
except:
    katz_centrality = {node: '' for node in G.nodes()}

# Girvan-Newmanアルゴリズムでコミュニティに分割
comp = girvan_newman(G)
communities = tuple(sorted(c) for c in next(comp))

# 各ノードがどのコミュニティに属するかを記録
community_map = {}
for i, community in enumerate(communities):
    for node in community:
        community_map[node] = i

# 中心性を新しいデータフレームに格納
centrality_df = pd.DataFrame({
    'Node': list(G.nodes()),
    'Degree Centrality': [degree_centrality[node] for node in G.nodes()],
    'Betweenness Centrality': [betweenness_centrality[node] for node in G.nodes()],
    'Closeness Centrality': [closeness_centrality[node] for node in G.nodes()],
    'Eigenvector Centrality': [eigenvector_centrality[node] for node in G.nodes()],
#    'Katz Centrality': [katz_centrality[node] for node in G.nodes()],
    'Community': [community_map[node] for node in G.nodes()]  # コミュニティ情報を追加
    })
#print(centrality_df)

file_name_comb = f"output/{company_code}_{company_name}_{date_time_string}_Centrality_{analyzed_links}.csv"
centrality_df.to_csv(file_name_comb, encoding="utf_8_sig", index=False)

# %%
#ネットワーク図を描画、ファイル出力
got_net = npm.kyoki_word_network(limited_df)
#フィルタボタンを表示させる場合は、set_optionを無効にする必要あり
#got_net.show_buttons(filter_=['physics'])
got_net.set_options("""
const options = {
  "physics": {
    "forceAtlas2Based": {
      "centralGravity": 0.1,
      "springLength": 25,
      "springConstant": 0.1
    },
    "minVelocity": 0.75,
    "solver": "forceAtlas2Based"
  }
}
""")
file_name_kyoki = f'output/{company_code}_{company_name}_{date_time_string}_kyoki_{analyzed_links}.html'
got_net.show(file_name_kyoki)
# Out:
#         <iframe
#             width="95%"
#             height="1000px"
#             src="output/temp_temp_20250228-075320_kyoki_350.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#処理した条件をテキストファイルに出力
file_name_condition=f'output/{company_code}_{company_name}_{date_time_string}_Condition.txt'

# ファイルを書き込みモードで開く
with open(file_name_condition, 'w') as file:
    # 各変数の値をテキストファイルに書き込む
    file.write(f"Company code = {company_code}\n")
    file.write(f"Company name = {company_name}\n")
    file.write(f"Industry = {industry}\n")
    file.write(f"File = {open_file}\n")
    file.write(f"Analysis area = {analysis_area}\n")
    file.write(f"Target Page = {man_page_index}\n")
    file.write(f"Analyzed Links = {analyzed_links}\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 12
#      10 file.write(f"File = {open_file}\n")
#      11 file.write(f"Analysis area = {analysis_area}\n")
# ---> 12 file.write(f"Target Page = {man_page_index}\n")
#      13 file.write(f"Analyzed Links = {analyzed_links}\n")
#
# NameError: name 'man_page_index' is not defined
