# %%
import xml.etree.ElementTree as ET
import html
import re
import pandas as pd
import logging
import MeCab
import fitz
import re
import sys
sys.path.append('/work_dir') 
import talknize_module_20240909 as tk
import csv
from collections import Counter
import itertools
import datetime
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import networkx as nx
from networkx.algorithms.community import girvan_newman
import network_plot_module as npm
import json

# %%
#前処理・関数定義領域

# %%
#形態素解析の前処理
#分析対象データの特性に対応するため、前処理はモジュールではなくコードとして記載
#talknize_module.pyにも標準的な処理も記載し、適宜使い分け可能にする

#----------------------------------------------------------------------
#テキストファイルの各行に記載された文字列を、処理用文字列として整形・リスト化
def text_to_list(file_path):

    # 空のリストを作成
    return_list = []
    try:
        # 指定されたファイルを読み込み、各行をリストに追加
        with open(file_path, 'r') as file:
            # ファイル内の各行をループし、行末の改行や余分な空白を除去してリストに格納
            return_list = [line.strip() for line in file]
    # ファイルが存在しない場合は例外を無視する
    except FileNotFoundError:
        pass
    # リストを返す
    return return_list

#----------------------------------------------------------------------
#形態素解析前のテキストデータ処理（
#形態素解析の前に、無駄な記号やヘッダ・フッタ等の文言をテキストから除外
def pre_tk(text, excl_list):

    replaced_text = text

    #exclusion_list処理前に処理する必要のあるもの
    #【特例処理】除外処理前に、文頭のこれら記号は「箇条書き」とみなし、続く文言を一文として扱う
    replaced_text = re.sub(r'^[■□▪▫▲△▶▷▸▹▼▽◆◇●〇]', '。\n', replaced_text)
    #replaced_text = re.sub(r'[〇●◇◆□■▶△▲▽▼▫▪▹▶▸]', '', replaced_text)#上記以外は除去

    exclusion_list = []    
    exclusion_file1 = "userdic/exclusion_phrases1.txt"  # 各企業の除外フレーズを記載したリスト
    exclusion_file2 = "userdic/exclusion_codes.txt"  # その他記号・年月日・URL等を除外するためのリスト
    #exclusion_file3 = "userdic/exclusion_phrases2.txt"  # 各企業の除外フレーズを記載したリスト2（pageinfoから都度取り込み）
#    exclusion_list = text_to_list(exclusion_file1) + text_to_list(exclusion_file2)+ text_to_list(exclusion_file3)
    exclusion_list = excl_list + text_to_list(exclusion_file1) + text_to_list(exclusion_file2)

    for pattern in exclusion_list:
        replaced_text = re.sub(pattern, ' ', replaced_text)

    return replaced_text

# %%
#形態素解析の後処理
#形態素解析結果（tokenリスト）から、ストップワード、特定の条件の文字列等を除外
#import fitz
#import re
from collections import OrderedDict
import re

def post_tk(token_list):
    
    replaced_list = token_list    

    # stopwords（ファイルに格納）を除去
    path_stopwords = "userdic/stopwords.txt"
    stopwords = text_to_list(path_stopwords)
    stopwords = list(OrderedDict.fromkeys(stopwords)) # 元の順序を保持しつつ、重複を除去（# Python 3.7以降）
    replaced_list = [t for t in replaced_list if t not in stopwords]
    
    # ひらがなのみの要素を除去
    kana_re = re.compile("^[ぁ-ゖ]+$")
    replaced_list = [t for t in replaced_list if not kana_re.match(t)]

    # アルファベット1文字のみの要素を除去
    alphabet_re = re.compile("^[a-zA-Z]$")
    replaced_list = [t for t in replaced_list if not alphabet_re.match(t)]

    #特定の形態の数値要素を除去
    number_re = re.compile("^[\d,]+")
    replaced_list = [t for t in replaced_list if not number_re.match(t)]

    
    return replaced_list

# %%
#XMLからのテキスト抽出に用いる関数

# ターゲットを判別する列に1が立っている行のkeyword行、すなわち読み込みたい目次名＝XMLタグを取得し、重複を除外
def load_target_table_of_contents(df, target_column):
    try:
        return (
            df.loc[df[target_column] == 1, 'keyword']
            .dropna()
            .drop_duplicates()
            .apply(str.strip)
            .tolist()
        )
    except:
        return []


def extract_content_by_keywords(xml_path, keyword_list):
    if not keyword_list:  # keyword_list が空なら空文字列を返す
        return ""

    tree = ET.parse(xml_path)
    root = tree.getroot()
    collected_text = []

    for page in root.findall('page'):
        tag_elem = page.find('tag')
        content_elem = page.find('content')

        if tag_elem is not None and content_elem is not None:
            tag_text = html.unescape((tag_elem.text or "").strip())

            # タグをカンマや全角カンマで分割し、前後の空白も削除
            tag_list = [t.strip() for t in re.split(r'[,]', tag_text) if t.strip()]

            # いずれかのタグがキーワードに完全一致するか
            if any(tag in keyword_list for tag in tag_list):
                raw_text = content_elem.text
                if raw_text:
                    decoded_text = html.unescape(raw_text)
                    cdata_match = re.search(r'<!\[CDATA\[(.*?)\]\]>', decoded_text, re.DOTALL)
                    if cdata_match:
                        collected_text.append(cdata_match.group(1).strip())

    return '\n\n'.join(collected_text)

# %%
# ログファイルの設定
log_filename = "data/logfile_TextMining.log"
logging.basicConfig(
    level=logging.INFO,  # ログレベルの設定 (DEBUG, INFO, WARNING, ERROR, CRITICAL)
    format="%(asctime)s - %(levelname)s - %(message)s",  # ログのフォーマット
    handlers=[
        logging.FileHandler(log_filename, mode="a", encoding="utf-8"),  # ファイルに記録
        #logging.StreamHandler()  # コンソールにも出力
    ]
)

# %%
#共通
data_folder = 'data'
base_folder = 'ir/2025'
info_folder = 'info'
target_info_file = 'target_company_20250513.csv'
target_info_path = data_folder + '/' + target_info_file
eliminate_list=[]

#==========================================================================
#動作モードの指定
#==========================================================================
#◆対象企業の読込方法   
#0はcsvファイルから順次読込・処理、1は個別に指定
company_selection_mode = 0
#◆XMLからの抽出範囲   
#0はcontents.csvで指定した範囲指定全て、1はマニュアル指定（リスト）
column_selection_mode = 0 
#◆出力ファイル出力方法　
#0は一つの企業ごとに複数の指定範囲を１ファイルで出力、1は企業ごと・指定範囲ごとに出力
file_output_mode =0 
#==========================================================================
#動作モードに応じた設定（csvから読み込まない場合、以下に記述）
#==========================================================================
#company_selection_mode = 1 の場合の個別指定項目
security_code = '79360'
company_name = 'アシックス'
industry_sector = 'その他製品'
target_folder = '79360_アシックス'
pdf_filename =  'file.pdf'
temp_list = [security_code, company_name, industry_sector, target_folder, pdf_filename]
#---------------------------------------------------------------------------
#column_selection_mode = 1 の場合の抽出条件グループ
#target_columns = ['経営者', '価値創造', 'ESG', '財務', '知的資本', '人的資本, '社会関係資本', '流通', 'マーケティング', 'all']
target_columns = ['経営者']
# contents.csvのうち抽出条件範囲でない列を除外：これはmodeによらず共通
excluded_columns = ['keyword', 'page', 'origin', '表示']
#---------------------------------------------------------------------------


#読込対象企業の企業名、格納フォルダ等の情報
#company_selection_modeに応じた処理
#company_selection_mode == 0の場合は指定したファイル（csv)から
if company_selection_mode == 0 :
    df_target_company_info = pd.read_csv(target_info_path)
else:
    df_target_company_info = pd.DataFrame([temp_list],columns=['コード','企業名','業種分類','格納フォルダ','統合報告書PDF'])
#df_target_company_info

# %%
#以下、企業単位で処理・出力
for index, row in df_target_company_info.iterrows():
    #target_folder = security_code + '_' + company_name

    target_columns = []
    df_count_combined = pd.DataFrame()
    df_combination_ex_combined = pd.DataFrame()    
    df_centrality_combined = pd.DataFrame()    

    #ファイル識別に利用する年月日文字列の取得（企業の処理単位で取得）
    # 現在の時刻情報を取得
    now = datetime.datetime.now()
    # 年月日と時刻の文字列を生成
    date_time_string = now.strftime("%Y%m%d-%H%M%S")
    time_string = now.strftime("%H%M%S")
    
    #行ごとの値を読み込み
    row_security_code = row['コード']
    row_company_name = row['企業名']
    row_industy_sector = row['業種分類']
    row_pdf_filename =  row['統合報告書PDF']
    row_xml_filename = row_pdf_filename[:len(row_pdf_filename)-4] + '.xml'
    row_target_folder = base_folder + '/' +row['格納フォルダ']#PDFと作成したXMLの格納先となるフォルダ
    row_xml_path = row_target_folder + '/' + row_xml_filename
    row_info_folder = row_target_folder + '/' + info_folder
    row_contents_csv = row_info_folder + '/' + 'contents.csv'
    #print(row_security_code, row_info_folder, row_xml_filename)
    print(f"Processing {row_xml_path}")

    # contents.CSVを読み込む
    df_tbl_of_cnt = pd.read_csv(row_contents_csv)
    #print(df_tbl_of_cnt)

    # column_selection_mode == 0の場合、テキストデータを取得する範囲の名称を動的に抽出
    #（column_selection_mode == 1の場合はtarget_columnsを手動で記載したものを読み込み）
    if column_selection_mode == 0:
        if df_tbl_of_cnt.empty:
            target_columns = []
        else:
            target_columns = [col for col in df_tbl_of_cnt.columns if col not in excluded_columns]
    #print(target_columns)
    
    
    # 各ターゲット列（target_columnsリストで指定された列）に応じた処理
    if target_columns == []:
        logging.info("target_columnsが空です。ターゲット列の処理はスキップします。")
    else:
        for col in target_columns:
            print(f"{col}")            
            #print(f"\n=== タグ: {col} ===\n")
            target_table_of_contents = load_target_table_of_contents(df_tbl_of_cnt, col)
            output_text = extract_content_by_keywords(row_xml_path, target_table_of_contents)
            #print(output_text)
    
            #'。'で改行、一文の範囲を明確にする
            separated_text = re.sub(r'。','。\n', output_text)
            tokenized_text_list = post_tk(tk.mecab_tokenizer(pre_tk(separated_text, eliminate_list)))
            #Merged_Extracted_tokenized_list = [item for _, sublist in Extracted_tokenized_page_text for item in sublist]
            #print(tokenized_text_list)
    
            #辞書形式で単語をカウント
            counter = Counter(tokenized_text_list)
            # 単語、件数をDataFrameに格納
            df_count = pd.DataFrame(list(counter.items()), columns=['単語', '件数'])
            # DataFrameを件数でソート
            df_count = df_count.sort_values(by='件数', ascending=False)

            #df_countが[]の場合（tokenized_listが[]の場合）は、単語リスト出力とワードクラウドの作成をスキップ
            if df_count.empty:
                logging.info(f"{row_company_name}で、{col}で指定した範囲で抽出された単語がありません。")
            else:
                # 新しい列を追加
                df_count.insert(0, '業種', row_industy_sector)
                df_count.insert(1, 'コード', row_security_code)
                df_count.insert(2, '企業名', row_company_name)
                df_count.insert(3, '分析範囲', col)
        
                #print(df_count)
        
                # 結果をCSVファイルに出力
                #個別に出力するパターン
                if file_output_mode == 1: 
                    file_name = f"output/WordList/{row_security_code}_{row_company_name}_{col}_Word_list_{date_time_string}.csv"
                    df_count.to_csv(file_name, encoding="utf_8_sig", index=False)        
                else:
                    df_count_combined = pd.concat([df_count_combined, df_count], ignore_index=True)            
    
                #抽出単語によるワードクラウド作成
                #ワードクラウド用設定
                # 日本語フォントのパスを指定
                jp_font_path = '/usr/share/fonts/opentype/ipaexfont-gothic/ipaexg.ttf'
                # ワードクラウドのフォーマット指定
                wordcloud = WordCloud(width=800, height=400, background_color='white',font_path=jp_font_path)
                # 単語とその頻度を辞書形式に変換
                word_freq = {word: freq for word, freq in zip(df_count['単語'], df_count['件数'])}
                # ワードクラウドの生成
                wordcloud.generate_from_frequencies(word_freq)
                # プロット
                plt.figure(figsize=(10, 5))
                plt.imshow(wordcloud, interpolation='bilinear')
                plt.axis('off')
                #plt.show()
                
                # 結果をpngファイルに出力
                file_name_wordcloud = f'output/WordCloud/{row_security_code}_{row_company_name}_{col}_WordCloud_{date_time_string}.png'
                wordcloud.to_file(file_name_wordcloud)
                plt.close()
                #plt.clf()
                #plt.close()
                #tf-idf用に、ファイル名、企業名、トークンを出力
                #とりあえず略
    
                #各文中の、形態素組み合わせを作る
                #一文単位でトークンリストを作る
                #print(output_text)
                #print(f"--------------------")
                #temp_sentences = [sentence for sentence in re.split("。", pre_tk(output_text, eliminate_list))]
                #print(temp_sentences)
                #print(f"--------------------")

                #sentences = [post_tk(tk.mecab_tokenizer(sentence)) for sentence in re.split("。", output_text)]
                #現在の改行か、句点「。」で文章を区切り、要素リストに区分する
                sentences = [post_tk(tk.mecab_tokenizer(sentence)) for sentence in re.split(r'[。\n]', pre_tk(output_text, eliminate_list))]
                #空の要素リスト（空行か、テキストマイニングの結果リスト要素がなくなったもの）を除外
                sentences = [lst for lst in sentences if lst]
                #print(sentences)
                #input()

                #各文のトークンの組み合わせを作る
                #従来は全部の組み合わせ
                #sentence_combs = [list(itertools.combinations(sentence,2)) for sentence in sentences]
                #隣接する指定文字数内のトークンの組み合わせに限定
                max_distance = 15
                sentence_combs = [
                    [(sentence[i], sentence[j]) 
                     for i in range(len(sentence)) 
                     for j in range(i + 1, min(i + 1 + max_distance, len(sentence)))]
                    for sentence in sentences
                ]

                #組み合わせた2つの形態素の並びをソート
                words_combs = [[tuple(sorted(words)) for words in sentence] for sentence in sentence_combs]
                #print(words_combs[0][:30])
                target_combs = []
                for words_comb in words_combs:
                    target_combs.extend(words_comb)
                ct = Counter(target_combs)
                #print(ct)
                df_combination = pd.DataFrame([{"1番目" : i[0][0], "2番目": i[0][1], "count":i[1]} for i in ct.most_common()])
                df_combination_ex = df_combination.copy()
                # 新しい列を追加
                df_combination_ex.insert(0, '業種', row_industy_sector)
                df_combination_ex.insert(1, 'コード', row_security_code)
                df_combination_ex.insert(2, '企業名', row_company_name)
                df_combination_ex.insert(3, '分析範囲', col)
        
                #print(df_combination_ex)
        
                #ファイル出力
                if file_output_mode == 1: 
                    file_name_comb = f"output/Co-Occurrence/{row_security_code}_{row_company_name}_{col}_Co-Occurrence_{date_time_string}.csv"
                    df_combination_ex.to_csv(file_name_comb, encoding="utf_8_sig", index=False)
                else:
                    df_combination_ex_combined = pd.concat([df_combination_ex_combined, df_combination_ex], ignore_index=True)  
        
                #########################################################
                # 分析対象とする共起単語の組み合わせ数（ノード数）を指定
                analyzed_links = 500
                limited_df = df_combination.head(analyzed_links)
                #########################################################
        
                # DataFrameからネットワークを作成
                G = nx.from_pandas_edgelist(limited_df, '1番目', '2番目', ['count'])
        
                # 各ノードの中心性を計算
                try:
                    degree_centrality = nx.degree_centrality(G)
                except:
                    degree_centrality = {node: '' for node in G.nodes()}
                    
                try:
                    betweenness_centrality = nx.betweenness_centrality(G)
                except:
                    betweenness_centrality = {node: '' for node in G.nodes()}
                
                try:
                    closeness_centrality = nx.closeness_centrality(G)
                except:
                    closeness_centrality = {node: '' for node in G.nodes()}
                
                try:
                    eigenvector_centrality = nx.eigenvector_centrality(G)
                except:
                    eigenvector_centrality = {node: '' for node in G.nodes()}
                
                try:
                    katz_centrality = nx.katz_centrality(G)
                except:
                    katz_centrality = {node: '' for node in G.nodes()}
                
                # Girvan-Newmanアルゴリズムでコミュニティに分割
                comp = girvan_newman(G)
                communities = tuple(sorted(c) for c in next(comp))
                
                # 各ノードがどのコミュニティに属するかを記録
                community_map = {}
                for i, community in enumerate(communities):
                    for node in community:
                        community_map[node] = i
                
                # 中心性を新しいデータフレームに格納
                df_centrality = pd.DataFrame({
                    'コード': row_security_code,
                    '企業名': row_company_name,
                    '分析範囲': col,
                    'Node': list(G.nodes()),
                    'Degree Centrality': [degree_centrality[node] for node in G.nodes()],
                    'Betweenness Centrality': [betweenness_centrality[node] for node in G.nodes()],
                    'Closeness Centrality': [closeness_centrality[node] for node in G.nodes()],
                    'Eigenvector Centrality': [eigenvector_centrality[node] for node in G.nodes()],
                #    'Katz Centrality': [katz_centrality[node] for node in G.nodes()],
                    'Community': [community_map[node] for node in G.nodes()]  # コミュニティ情報を追加
                    })
                #print(df_centrality)
        
                if file_output_mode == 1: 
                    file_name_centrality = f"output/Centrality/{row_security_code}_{row_company_name}_{col}_Centrality_{analyzed_links}_{date_time_string}.csv"
                    df_centrality.to_csv(file_name_centrality, encoding="utf_8_sig", index=False)
                else:
                    df_centrality_combined = pd.concat([df_centrality_combined, df_centrality], ignore_index=True)
                
                #ネットワーク図を描画、ファイル出力
                got_net = npm.kyoki_word_network(limited_df)
                #フィルタボタンを表示させる場合は、set_optionを無効にする必要あり
                #got_net.show_buttons(filter_=['physics'])
                got_net.set_options("""
                const options = {
                  "physics": {
                    "forceAtlas2Based": {
                      "centralGravity": 0.1,
                      "springLength": 25,
                      "springConstant": 0.1
                    },
                    "minVelocity": 0.75,
                    "solver": "forceAtlas2Based"
                  }
                }
                """)
                file_name_kyoki = f'output/Kyoki/{row_security_code}_{row_company_name}_{col}_kyoki_{analyzed_links}_{date_time_string}_.html'
                got_net.show(file_name_kyoki)

    
    if file_output_mode != 1:
        file_name = f"output/WordList/{row_security_code}_{row_company_name}_combined_Word_list_{date_time_string}.csv"
        df_count_combined.to_csv(file_name, encoding="utf_8_sig", index=False)

        file_name_comb = f"output/Co-Occurrence/{row_security_code}_{row_company_name}_combined_Co-Occurrence_{date_time_string}.csv"
        df_combination_ex_combined.to_csv(file_name_comb, encoding="utf_8_sig", index=False)

        file_name_centrality = f"output/Centrality/{row_security_code}_{row_company_name}_combined_Centrality_{analyzed_links}_{date_time_string}.csv"
        df_centrality_combined.to_csv(file_name_centrality, encoding="utf_8_sig", index=False)

    print(f"processed {row_target_folder}/{row_xml_filename} at {date_time_string}.")
    logging.info(f"processed {row_target_folder}/{row_xml_filename} at {date_time_string}.")
# Out:
# Processing ir/2025/20020_日清製粉グループ本社/Gx5z.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/20020_日清製粉グループ本社/Gx5z.xml at 20250513-230452.
# Processing ir/2025/22690_明治ホールディングス/integratedreports-integrated_reports_2024_ja_all.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/22690_明治ホールディングス/integratedreports-integrated_reports_2024_ja_all.xml at 20250513-230630.
# Processing ir/2025/26070_不二製油グループ本社/fujioil_integrated_report2024_01.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/26070_不二製油グループ本社/fujioil_integrated_report2024_01.xml at 20250513-230821.
# Processing ir/2025/28020_味の素/ASV_Report_2024_A3_jp .xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/28020_味の素/ASV_Report_2024_A3_jp .xml at 20250513-231055.
# Processing ir/2025/31010_東洋紡/TOYOBOREPORT2024_JP.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/31010_東洋紡/TOYOBOREPORT2024_JP.xml at 20250513-231249.
# Processing ir/2025/34010_帝人/00.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/34010_帝人/00.xml at 20250513-231449.
# Processing ir/2025/38610_王子ホールディングス/2024_all_ja.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/38610_王子ホールディングス/2024_all_ja.xml at 20250513-231716.
# Processing ir/2025/38800_大王製紙/DAIO_2024_all.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/38800_大王製紙/DAIO_2024_all.xml at 20250513-231947.
# Processing ir/2025/34070_旭化成/24jp.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/34070_旭化成/24jp.xml at 20250513-232213.
# Processing ir/2025/40050_住友化学/scr2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/40050_住友化学/scr2024.xml at 20250513-232441.
# Processing ir/2025/40210_日産化学/ar2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/40210_日産化学/ar2024.xml at 20250513-232648.
# Processing ir/2025/40280_石原産業/2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/40280_石原産業/2024.xml at 20250513-232850.
# Processing ir/2025/40420_東ソー/report2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/40420_東ソー/report2024.xml at 20250513-233057.
# Processing ir/2025/40440_セントラル硝子/rc_2024_all_forspread.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 流通
# マーケティング
# all
# processed ir/2025/40440_セントラル硝子/rc_2024_all_forspread.xml at 20250513-233312.
# Processing ir/2025/40630_信越化学工業/統合報告書2024（閲覧推奨）.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/40630_信越化学工業/統合報告書2024（閲覧推奨）.xml at 20250513-233454.
# Processing ir/2025/40780_堺化学工業/all_sakaikagaku_ir2024_jp.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/40780_堺化学工業/all_sakaikagaku_ir2024_jp.xml at 20250513-233646.
# Processing ir/2025/40920_日本化学工業/integrated_report2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/40920_日本化学工業/integrated_report2024.xml at 20250513-233833.
# Processing ir/2025/41140_日本触媒/TechnoAmenityReport2024_jp.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 社会関係資本.1
# 流通
# マーケティング
# all
# processed ir/2025/41140_日本触媒/TechnoAmenityReport2024_jp.xml at 20250513-234032.
# Processing ir/2025/41830_三井化学/ar24_all_jp_A4.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/41830_三井化学/ar24_all_jp_A4.xml at 20250513-234206.
# Processing ir/2025/41880_三菱ケミカルグループ/24.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/41880_三菱ケミカルグループ/24.xml at 20250513-234349.
# Processing ir/2025/42020_ダイセル/daicel_report_2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/42020_ダイセル/daicel_report_2024.xml at 20250513-234546.
# Processing ir/2025/42050_日本ゼオン/240930.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/42050_日本ゼオン/240930.xml at 20250513-234742.
# Processing ir/2025/42720_日本化薬/integrated_report_2024_a3.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/42720_日本化薬/integrated_report_2024_a3.xml at 20250513-234933.
# Processing ir/2025/44610_第一工業製薬/rc2024m.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/44610_第一工業製薬/rc2024m.xml at 20250513-235202.
# Processing ir/2025/49010_富士フイルムホールディングス/fh_2024_allj_a4.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/49010_富士フイルムホールディングス/fh_2024_allj_a4.xml at 20250513-235358.
# Processing ir/2025/69880_日東電工/2024_all.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/69880_日東電工/2024_all.xml at 20250513-235611.
# Processing ir/2025/45020_武田薬品工業/takeda_2024_annual_integrated_report_jp.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45020_武田薬品工業/takeda_2024_annual_integrated_report_jp.xml at 20250513-235805.
# Processing ir/2025/45210_科研製薬/cr_2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45210_科研製薬/cr_2024.xml at 20250513-235902.
# Processing ir/2025/45230_エーザイ/pdf2024vcr_1.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45230_エーザイ/pdf2024vcr_1.xml at 20250514-000040.
# Processing ir/2025/45270_ロート製薬/wb_report_2024_v3.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45270_ロート製薬/wb_report_2024_v3.xml at 20250514-000213.
# Processing ir/2025/45280_小野薬品工業/ono_ir24_a3.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45280_小野薬品工業/ono_ir24_a3.xml at 20250514-000406.
# Processing ir/2025/45300_久光製薬/Integrated_report2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45300_久光製薬/Integrated_report2024.xml at 20250514-000603.
# Processing ir/2025/45340_持田製薬/ir2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45340_持田製薬/ir2024.xml at 20250514-000742.
# Processing ir/2025/45360_参天製薬/ar2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45360_参天製薬/ar2024.xml at 20250514-000914.
# Processing ir/2025/45470_キッセイ薬品工業/283c4d68f90d4edf11107c36f9627bce_1.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45470_キッセイ薬品工業/283c4d68f90d4edf11107c36f9627bce_1.xml at 20250514-001057.
# Processing ir/2025/45680_第一三共/DS2024_all.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45680_第一三共/DS2024_all.xml at 20250514-001220.
# Processing ir/2025/45690_杏林製薬/AR2024JA.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45690_杏林製薬/AR2024JA.xml at 20250514-001345.
# Processing ir/2025/50190_出光興産/00.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/50190_出光興産/00.xml at 20250514-001454.
# Processing ir/2025/50200_ＥＮＥＯＳホールディングス/00.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/50200_ＥＮＥＯＳホールディングス/00.xml at 20250514-001714.
# Processing ir/2025/52320_住友大阪セメント/soc_InR_2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/52320_住友大阪セメント/soc_InR_2024.xml at 20250514-001919.
# Processing ir/2025/53330_日本碍子/ngk2024_a3.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/53330_日本碍子/ngk2024_a3.xml at 20250514-002101.
# Processing ir/2025/53340_日本特殊陶業/ir_integration_report_08.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/53340_日本特殊陶業/ir_integration_report_08.xml at 20250514-002300.
# Processing ir/2025/54010_日本製鉄/nsc_jp_ir_2024_all_interactive.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/54010_日本製鉄/nsc_jp_ir_2024_all_interactive.xml at 20250514-002528.
# Processing ir/2025/54060_神戸製鋼所/integrated-reports2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/54060_神戸製鋼所/integrated-reports2024.xml at 20250514-002851.
# Processing ir/2025/54110_ＪＦＥホールディングス/all.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/54110_ＪＦＥホールディングス/all.xml at 20250514-003121.
# Processing ir/2025/57110_三菱マテリアル/00.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/57110_三菱マテリアル/00.xml at 20250514-003335.
# Processing ir/2025/57270_東邦チタニウム/csr_2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/57270_東邦チタニウム/csr_2024.xml at 20250514-003558.
# Processing ir/2025/58020_住友電気工業/integratedreport2024_4.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/58020_住友電気工業/integratedreport2024_4.xml at 20250514-003709.
# Processing ir/2025/57060_三井金属鉱業/integrated_report2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/57060_三井金属鉱業/integrated_report2024.xml at 20250514-003840.
# Processing ir/2025/60130_タクマ/report-2024A3.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/60130_タクマ/report-2024A3.xml at 20250514-004046.
# Processing ir/2025/63320_月島ホールディングス/h6wG.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/63320_月島ホールディングス/h6wG.xml at 20250514-004249.
# Processing ir/2025/63670_ダイキン工業/2024-pdf.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/63670_ダイキン工業/2024-pdf.xml at 20250514-004416.
# Processing ir/2025/63700_栗田工業/annual_2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/63700_栗田工業/annual_2024.xml at 20250514-004637.
# Processing ir/2025/64720_ＮＴＮ/ntn_report2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/64720_ＮＴＮ/ntn_report2024.xml at 20250514-004833.
# Processing ir/2025/64900_PILLAR/PILLAR_Integrated-report_2024_A3-2.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/64900_PILLAR/PILLAR_Integrated-report_2024_A3-2.xml at 20250514-005020.
# Processing ir/2025/70110_三菱重工業/report_2024_a3.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/70110_三菱重工業/report_2024_a3.xml at 20250514-005149.
# Processing ir/2025/64480_ブラザー工業/ful-a3-j.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/64480_ブラザー工業/ful-a3-j.xml at 20250514-005347.
# Processing ir/2025/65010_日立製作所/ar2024j.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/65010_日立製作所/ar2024j.xml at 20250514-005539.
# Processing ir/2025/65040_富士電機/ar2024all.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/65040_富士電機/ar2024all.xml at 20250514-005713.
# Processing ir/2025/65250_ＫＯＫＵＳＡＩ_ＥＬＥＣＴＲＩＣ/00.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/65250_ＫＯＫＵＳＡＩ_ＥＬＥＣＴＲＩＣ/00.xml at 20250514-005905.
# Processing ir/2025/66450_オムロン/OMRON_Integrated_Report_2024_jp_A4.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/66450_オムロン/OMRON_Integrated_Report_2024_jp_A4.xml at 20250514-010050.
# Processing ir/2025/66740_ジーエス・ユアサ_コーポレーション/GS_Yuasa_Report_2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/66740_ジーエス・ユアサ_コーポレーション/GS_Yuasa_Report_2024.xml at 20250514-010319.
# Processing ir/2025/67010_日本電気/etsuran.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/67010_日本電気/etsuran.xml at 20250514-010542.
# Processing ir/2025/67020_富士通/integrated-report-2024-jp.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/67020_富士通/integrated-report-2024-jp.xml at 20250514-010659.
# Processing ir/2025/67240_セイコーエプソン/epson_ir2024_all_j.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/67240_セイコーエプソン/epson_ir2024_all_j.xml at 20250514-010902.
# Processing ir/2025/67520_パナソニック_ホールディングス/pana_ar2024j_a4.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/67520_パナソニック_ホールディングス/pana_ar2024j_a4.xml at 20250514-011110.
# Processing ir/2025/67580_ソニーグループ/CorporateReport2024_J.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/67580_ソニーグループ/CorporateReport2024_J.xml at 20250514-011259.
# Processing ir/2025/68100_マクセル/MAX_IR24_J.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/68100_マクセル/MAX_IR24_J.xml at 20250514-011448.
# Processing ir/2025/68140_古野電気/IR2024_jp_A3.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/68140_古野電気/IR2024_jp_A3.xml at 20250514-011651.
# Processing ir/2025/68410_横河電機/ir_2024yreports.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/68410_横河電機/ir_2024yreports.xml at 20250514-011816.
# Processing ir/2025/69520_カシオ計算機/integrated-2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/69520_カシオ計算機/integrated-2024.xml at 20250514-011956.
# Processing ir/2025/69630_ローム/JP_rohm_group_integrated_report_2024_view.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/69630_ローム/JP_rohm_group_integrated_report_2024_view.xml at 20250514-012136.
# Processing ir/2025/69760_太陽誘電/EpSk.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/69760_太陽誘電/EpSk.xml at 20250514-012346.
# Processing ir/2025/72760_小糸製作所/8d0b34baa07db41a5a718ac9ec40e985ba10138f.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/72760_小糸製作所/8d0b34baa07db41a5a718ac9ec40e985ba10138f.xml at 20250514-012526.
# Processing ir/2025/77350_ＳＣＲＥＥＮホールディングス/SCREEN_ARJ_2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/77350_ＳＣＲＥＥＮホールディングス/SCREEN_ARJ_2024.xml at 20250514-012657.
# Processing ir/2025/77520_リコー/all_J_spread.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/77520_リコー/all_J_spread.xml at 20250514-012912.
# Processing ir/2025/67530_シャープ/annual_2024j_int.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/67530_シャープ/annual_2024j_int.xml at 20250514-013053.
# Processing ir/2025/69020_デンソー/annual-report-doc-2024-viewing-ja.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/69020_デンソー/annual-report-doc-2024-viewing-ja.xml at 20250514-013141.
# Processing ir/2025/70120_川崎重工業/24_houkokusyo.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/70120_川崎重工業/24_houkokusyo.xml at 20250514-013353.
# Processing ir/2025/72590_アイシン/aisin_ar2024_a3.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/72590_アイシン/aisin_ar2024_a3.xml at 20250514-013634.
# Processing ir/2025/72670_本田技研工業/Honda_Report_2024-jp-all.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/72670_本田技研工業/Honda_Report_2024-jp-all.xml at 20250514-013855.
# Processing ir/2025/72700_ＳＵＢＡＲＵ/Ir2024j.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/72700_ＳＵＢＡＲＵ/Ir2024j.xml at 20250514-014207.
# Processing ir/2025/62010_豊田自動織機/TICOReport2024_J_full_view.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/62010_豊田自動織機/TICOReport2024_J_full_view.xml at 20250514-014413.
# Processing ir/2025/72030_トヨタ自動車/2024_001_integrated_jp.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/72030_トヨタ自動車/2024_001_integrated_jp.xml at 20250514-014612.
# Processing ir/2025/45430_テルモ/TR2024_all_J.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45430_テルモ/TR2024_all_J.xml at 20250514-014900.
# Processing ir/2025/77010_島津製作所/shimadzu_integrated_report_2024-r.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/77010_島津製作所/shimadzu_integrated_report_2024-r.xml at 20250514-015108.
# Processing ir/2025/77410_ＨＯＹＡ/online_report2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/77410_ＨＯＹＡ/online_report2024.xml at 20250514-015333.
# Processing ir/2025/77470_朝日インテック/朝日インテックグループ 統合報告書2024【日本語版】_0.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/77470_朝日インテック/朝日インテックグループ 統合報告書2024【日本語版】_0.xml at 20250514-015517.
# Processing ir/2025/77800_メニコン/20241015132353435s.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/77800_メニコン/20241015132353435s.xml at 20250514-015737.
# Processing ir/2025/79110_ＴＯＰＰＡＮホールディングス/00.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/79110_ＴＯＰＰＡＮホールディングス/00.xml at 20250514-015911.
# Processing ir/2025/79510_ヤマハ/an-2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/79510_ヤマハ/an-2024.xml at 20250514-020117.
# Processing ir/2025/13770_サカタのタネ/SAKATA20240527_sustainability_report_2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/13770_サカタのタネ/SAKATA20240527_sustainability_report_2024.xml at 20250514-020317.
# Processing ir/2025/19690_高砂熱学工業/cr_2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/19690_高砂熱学工業/cr_2024.xml at 20250514-020416.
# Processing ir/2025/63300_東洋エンジニアリング/TOYO_IR2024_Ja-compressed.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/63300_東洋エンジニアリング/TOYO_IR2024_Ja-compressed.xml at 20250514-020635.
# Processing ir/2025/45440_Ｈ．Ｕ．グループホールディングス/hugp_report_2024_j_HP_2.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45440_Ｈ．Ｕ．グループホールディングス/hugp_report_2024_j_HP_2.xml at 20250514-020826.
# Processing ir/2025/59380_ＬＩＸＩＬ/00.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/59380_ＬＩＸＩＬ/00.xml at 20250514-020950.
# Processing ir/2025/80120_長瀬産業/nagase2024_IR_Full.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/80120_長瀬産業/nagase2024_IR_Full.xml at 20250514-021118.
# Processing ir/2025/80150_豊田通商/ar2024_all.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/80150_豊田通商/ar2024_all.xml at 20250514-021301.
# Processing ir/2025/80880_岩谷産業/integrated_report.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/80880_岩谷産業/integrated_report.xml at 20250514-021522.
# Processing ir/2025/90200_東日本旅客鉄道/all.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/90200_東日本旅客鉄道/all.xml at 20250514-021648.
# Processing ir/2025/94320_日本電信電話/integrated_report_24j.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/94320_日本電信電話/integrated_report_24j.xml at 20250514-021915.
# Processing ir/2025/96130_ＮＴＴデータグループ/ar24_j_all_b_01.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/96130_ＮＴＴデータグループ/ar24_j_all_b_01.xml at 20250514-022120.
# Processing ir/2025/25010_サッポロホールディングス/integrated_report_2023.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/25010_サッポロホールディングス/integrated_report_2023.xml at 20250514-022325.
# Processing ir/2025/25030_キリンホールディングス/kirinreport2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/25030_キリンホールディングス/kirinreport2024.xml at 20250514-022514.
# Processing ir/2025/29140_日本たばこ産業/integrated2023_J_all.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# Unnamed: 11
# all
# processed ir/2025/29140_日本たばこ産業/integrated2023_J_all.xml at 20250514-022645.
# Processing ir/2025/40040_レゾナック・ホールディングス/pdf-sustainability-report-integratedreport-RESONAC24J_spread.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/40040_レゾナック・ホールディングス/pdf-sustainability-report-integratedreport-RESONAC24J_spread.xml at 20250514-022840.
# Processing ir/2025/40250_多木化学/sustainability_report_2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/40250_多木化学/sustainability_report_2024.xml at 20250514-023056.
# Processing ir/2025/44520_花王/reports-fy2024j.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/44520_花王/reports-fy2024j.xml at 20250514-023152.
# Processing ir/2025/46120_日本ペイントホールディングス/IntegratedReport_2024_all_jp.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/46120_日本ペイントホールディングス/IntegratedReport_2024_all_jp.xml at 20250514-023302.
# Processing ir/2025/46310_ＤＩＣ/dic_report_ja_2024_detail_printing.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/46310_ＤＩＣ/dic_report_ja_2024_detail_printing.xml at 20250514-023515.
# Processing ir/2025/46330_サカタインクス/Integrated_Report_2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/46330_サカタインクス/Integrated_Report_2024.xml at 20250514-023812.
# Processing ir/2025/49120_ライオン/ir2024.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/49120_ライオン/ir2024.xml at 20250514-024037.
# Processing ir/2025/49220_コーセー/report2024-all.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/49220_コーセー/report2024-all.xml at 20250514-024217.
# Processing ir/2025/49270_ポーラ・オルビスホールディングス/IntegratedReport2023_A3_s_20240930.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/49270_ポーラ・オルビスホールディングス/IntegratedReport2023_A3_s_20240930.xml at 20250514-024337.
# Processing ir/2025/45190_中外製薬/jAR2023_12_spread.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45190_中外製薬/jAR2023_12_spread.xml at 20250514-024522.
# Processing ir/2025/45780_大塚ホールディングス/2024_all_a4.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/45780_大塚ホールディングス/2024_all_a4.xml at 20250514-024655.
# Processing ir/2025/51010_横浜ゴム/sustainability2024_a4.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/51010_横浜ゴム/sustainability2024_a4.xml at 20250514-024853.
# Processing ir/2025/51080_ブリヂストン/ir2024_single.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/51080_ブリヂストン/ir2024_single.xml at 20250514-025935.
# Processing ir/2025/53100_東洋炭素/00.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/53100_東洋炭素/00.xml at 20250514-030145.
# Processing ir/2025/63260_クボタ/integratedreport2024-a4-full.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/63260_クボタ/integratedreport2024-a4-full.xml at 20250514-030253.
# Processing ir/2025/63610_荏原製作所/INT24_all_print_JP.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/63610_荏原製作所/INT24_all_print_JP.xml at 20250514-030452.
# Processing ir/2025/68560_堀場製作所/20240509_HR_jp.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/68560_堀場製作所/20240509_HR_jp.xml at 20250514-030738.
# Processing ir/2025/63760_日機装/00.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/63760_日機装/00.xml at 20250514-030904.
# Processing ir/2025/79150_ＮＩＳＳＨＡ/NisshaReport2024_A4.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/79150_ＮＩＳＳＨＡ/NisshaReport2024_A4.xml at 20250514-031030.
# Processing ir/2025/79360_アシックス/file.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/79360_アシックス/file.xml at 20250514-031234.
# Processing ir/2025/49110_資生堂/report_jp.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/49110_資生堂/report_jp.xml at 20250514-031359.
# Processing ir/2025/49960_クミアイ化学工業/ar2024_all.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/49960_クミアイ化学工業/ar2024_all.xml at 20250514-031529.
# Processing ir/2025/77510_キヤノン/canon-int-2025-j.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/77510_キヤノン/canon-int-2025-j.xml at 20250514-031710.
# Processing ir/2025/41510_協和キリン/Integrated report 2024_JP.xml
# 経営者
# 価値創造
# ESG
# 財務
# 知的資本
# 人的資本
# 社会関係資本
# 流通
# マーケティング
# all
# processed ir/2025/41510_協和キリン/Integrated report 2024_JP.xml at 20250514-031902.
