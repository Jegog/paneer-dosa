# %%
from lxml import etree

# XBRLファイルの読み込み
tree = etree.parse('data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl')
root = tree.getroot()

# ルート要素のタグを表示
print(root.tag)
# Out:
# {http://www.xbrl.org/2003/instance}xbrl

# %%
from bs4 import BeautifulSoup
import re

with open('data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl', 'r') as file:
    soup = BeautifulSoup(file, 'xml')

# 例：特定のタグの取得
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')
for elem in elements:
    print(elem.text)
# Out:
# <h3>２ 【サステナビリティに関する考え方及び取組】</h3>
# <p style="margin-left: 24px; text-align: justify; text-justify: inter-ideograph">
# <span style="font-size: 14px">(1)サステナビリティ全般</span>
# </p>
#
# <p style="margin-left: 36px; text-align: justify; text-justify: inter-ideograph; text-indent: 1.8px">
# <span style="font-size: 14px">①ガバナンス</span>
# </p>
# <p style="margin-left: 46.666666666666666666666666667px; text-align: justify; text-justify: inter-ideograph; text-indent: 1.8px">ア．サステナビリティの考え方</p>
# <p style="margin-left: 46.666666666666666666666666667px; text-align: justify; text-justify: inter-ideograph; text-indent: 12px">三菱電機グループは、「企業理念」「私たちの価値観」「コミットメント」に則り、全ての活動においてサステナビリティを志向した取組みを行います。また、「『事業を通じた社会課題の解決』という原点に立ち、サステナビリティの実現を経営の根幹に位置づける。これにより、企業価値の持続的向上を図り、社会・顧客・株主・従業員をはじめとしたステークホルダーへの責任を果たす」ことを経営方針に掲げています。社会からの期待や要請・意見を活動に反映させ、社会や環境に与えるネガティブな影響を最小化し、持続可能な社会の実現に向けた取組みを推進します。</p>
# ...

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
with open('data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl', 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 対象の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# 特定のタグを保持
allowed_tags = {'table', 'tr', 'td'}

# タグの属性を削除し、特定のタグ以外を削除
for elem in elements:
    for tag in elem.find_all():
        if tag.name not in allowed_tags:
            # タグの内容を保持して親タグに追加
            tag.unwrap()
        else:
            # 属性を削除
            tag.attrs = {}
            #tag.string = tag.get_text(strip=True)

# 結果を出力
i=0
for elem in elements:
    print(i)
    print('------------------------------------')
    print(elem)
    print('------------------------------------')
    i=i+1
print(i)
# Out:
# 0
# ------------------------------------
# <jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock contextRef="FilingDateInstant">
# ２ 【サステナビリティに関する考え方及び取組】
#
# (1)サステナビリティ全般
#
#
# ①ガバナンス
#
# ア．サステナビリティの考え方
# 三菱電機グループは、「企業理念」「私たちの価値観」「コミットメント」に則り、全ての活動においてサステナビリティを志向した取組みを行います。また、「『事業を通じた社会課題の解決』という原点に立ち、サステナビリティの実現を経営の根幹に位置づける。これにより、企業価値の持続的向上を図り、社会・顧客・株主・従業員をはじめとしたステークホルダーへの責任を果たす」ことを経営方針に掲げています。社会からの期待や要請・意見を活動に反映させ、社会や環境に与えるネガティブな影響を最小化し、持続可能な社会の実現に向けた取組みを推進します。
#
# イ．サステナビリティの実現に向けた推進事項
# サステナビリティの実現に向け、以下の4点を推進事項としています。
#
# <table>
#
#
#
#
#
# <tr>
# <td>
# 持続可能な社会に
# 事業で貢献
# </td>
# <td>
# 事業を通じて社会課題や環境課題を解決し、「活力とゆとりある社会の実現」に貢献すること。
# </td>
# </tr>
# <tr>
# <td>
# 持続可能な社会への責任
# </td>
# <td>
# 社会課題や環境課題を引き起こさない・拡大させないよう、責任ある企業活動を行うこと。
# </td>
# </tr>
# <tr>
# <td>
# 長期の社会変化、
# 環境変化に対応する
# リスク管理
# </td>
# <td>
# 短期的・中期的のみならず、長期的な社会変化・環境変化に適応すること。事業機会を創出して企業を持続的に発展させること。リスクを予測し、企業経営に与える影響を抑制・最小化すること。
# </td>
# </tr>
# <tr>
# <td>
# ステークホルダーとの
# ...

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
with open('data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl', 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 対象の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# 特定のタグを保持
allowed_tags = {'table', 'tr', 'td'}

# タグの属性を削除し、特定のタグ以外を削除
for elem in elements:
    for tag in elem.find_all():
        if tag.name not in allowed_tags:
            # タグの内容を保持して親タグに追加
            tag.unwrap()
        else:
            # 属性を削除
            tag.attrs = {}
            # 改行を除去
            if tag.name in {'tr', 'td'}:
                tag.string = tag.get_text(strip=True).replace('\n', '')

# 結果を出力
i = 0
for elem in elements:
    print(i)
    print('------------------------------------')
    print(elem)
    print('------------------------------------')
    i = i + 1
print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 25
#      22 for tag in elem.find_all():
#      23     if tag.name not in allowed_tags:
#      24         # タグの内容を保持して親タグに追加
# ---> 25         tag.unwrap()
#      26     else:
#      27         # 属性を削除
#      28         tag.attrs = {}
#
# File /usr/local/lib/python3.8/site-packages/bs4/element.py:327, in PageElement.unwrap(self)
#     325 my_parent = self.parent
#     326 if self.parent is None:
# --> 327     raise ValueError(
#     328         "Cannot replace an element with its contents when that"
#     329         "element is not part of a tree.")
#     330 my_index = self.parent.index(self)
#     331 self.extract(_self_index=my_index)
#
# ValueError: Cannot replace an element with its contents when thatelement is not part of a tree.

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
with open('data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl', 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 対象の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# 特定のタグを保持
allowed_tags = {'table', 'tr', 'td'}

# タグの属性を削除し、特定のタグ以外を削除
for elem in elements:
    for tag in elem.find_all():
        if tag.name not in allowed_tags:
            # タグの内容を保持して親タグに追加
            tag.unwrap()
        else:
            # 属性を削除
            tag.attrs = {}
            # 改行を除去
            if tag.name in {'tr', 'td'}:
                text = tag.get_text(strip=True).replace('\n', '')
                tag.clear()  # タグの内容をクリア
                tag.append(text)  # 新しいテキストノードを追加

# 結果を出力
i = 0
for elem in elements:
    print(i)
    print('------------------------------------')
    print(elem)
    print('------------------------------------')
    i = i + 1
print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 25
#      22 for tag in elem.find_all():
#      23     if tag.name not in allowed_tags:
#      24         # タグの内容を保持して親タグに追加
# ---> 25         tag.unwrap()
#      26     else:
#      27         # 属性を削除
#      28         tag.attrs = {}
#
# File /usr/local/lib/python3.8/site-packages/bs4/element.py:327, in PageElement.unwrap(self)
#     325 my_parent = self.parent
#     326 if self.parent is None:
# --> 327     raise ValueError(
#     328         "Cannot replace an element with its contents when that"
#     329         "element is not part of a tree.")
#     330 my_index = self.parent.index(self)
#     331 self.extract(_self_index=my_index)
#
# ValueError: Cannot replace an element with its contents when thatelement is not part of a tree.

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
with open('data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl', 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 対象の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# 特定のタグを保持
allowed_tags = {'table', 'tr', 'td'}

# タグの属性を削除し、特定のタグ以外を削除
for elem in elements:
    for tag in elem.find_all():
        if tag.name not in allowed_tags:
            # タグの内容を保持して親タグに追加
            tag.unwrap()
        else:
            # 属性を削除
            tag.attrs = {}
            # 改行を除去
            if tag.name in {'tr', 'td'}:
                new_content = ''.join(str(c).replace('\n', '').replace(' ', '') for c in tag.contents)
                tag.clear()
                tag.append(BeautifulSoup(new_content, 'html.parser'))

# 結果を出力
i = 0
for elem in elements:
    print(i)
    print('------------------------------------')
    print(elem)
    print('------------------------------------')
    i = i + 1
print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 25
#      22 for tag in elem.find_all():
#      23     if tag.name not in allowed_tags:
#      24         # タグの内容を保持して親タグに追加
# ---> 25         tag.unwrap()
#      26     else:
#      27         # 属性を削除
#      28         tag.attrs = {}
#
# File /usr/local/lib/python3.8/site-packages/bs4/element.py:327, in PageElement.unwrap(self)
#     325 my_parent = self.parent
#     326 if self.parent is None:
# --> 327     raise ValueError(
#     328         "Cannot replace an element with its contents when that"
#     329         "element is not part of a tree.")
#     330 my_index = self.parent.index(self)
#     331 self.extract(_self_index=my_index)
#
# ValueError: Cannot replace an element with its contents when thatelement is not part of a tree.

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
with open('data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl', 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 対象の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# 特定のタグを保持
allowed_tags = {'table', 'tr', 'td'}

# タグの属性を削除し、特定のタグ以外を削除
for elem in elements:
    for tag in elem.find_all():
        if tag.name not in allowed_tags:
            # タグの内容を保持して親タグに追加
            tag.replace_with(BeautifulSoup(tag.decode_contents(), 'html.parser'))
        else:
            # 属性を削除
            tag.attrs = {}
            # 改行を除去
            if tag.name in {'tr', 'td'}:
                new_content = ''.join(str(c).replace('\n', '').replace(' ', '') for c in tag.contents)
                tag.clear()
                tag.append(BeautifulSoup(new_content, 'html.parser'))

# 結果を出力
i = 0
for elem in elements:
    print(i)
    print('------------------------------------')
    print(elem)
    print('------------------------------------')
    i = i + 1
print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 25
#      22 for tag in elem.find_all():
#      23     if tag.name not in allowed_tags:
#      24         # タグの内容を保持して親タグに追加
# ---> 25         tag.replace_with(BeautifulSoup(tag.decode_contents(), 'html.parser'))
#      26     else:
#      27         # 属性を削除
#      28         tag.attrs = {}
#
# File /usr/local/lib/python3.8/site-packages/bs4/element.py:305, in PageElement.replace_with(self, *args)
#     298 """Replace this PageElement with one or more PageElements, keeping the
#     299 rest of the tree the same.
#     300
#     301 :param args: One or more PageElements.
#     302 :return: `self`, no longer part of the tree.
#     303 """
#     304 if self.parent is None:
# --> 305     raise ValueError(
#     306         "Cannot replace one element with another when the "
# ...

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
with open('data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl', 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 対象の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# 特定のタグを保持
allowed_tags = {'table', 'tr', 'td'}

# タグの属性を削除し、特定のタグ以外を削除
for elem in elements:
    for tag in elem.find_all():
        if tag.name not in allowed_tags:
            # タグの内容を保持して親タグに追加
            content = tag.decode_contents(formatter="html")
            tag.insert_before(BeautifulSoup(content, 'html.parser'))
            tag.decompose()  # タグを削除
        else:
            # 属性を削除
            tag.attrs = {}
            # 改行を除去
            if tag.name in {'tr', 'td'}:
                text = ''.join(str(c).replace('\n', '').replace(' ', '') for c in tag.contents)
                tag.clear()
                tag.append(text)

# 結果を出力
i = 0
for elem in elements:
    print(i)
    print('------------------------------------')
    print(elem)
    print('------------------------------------')
    i = i + 1
print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 26
#      23 if tag.name not in allowed_tags:
#      24     # タグの内容を保持して親タグに追加
#      25     content = tag.decode_contents(formatter="html")
# ---> 26     tag.insert_before(BeautifulSoup(content, 'html.parser'))
#      27     tag.decompose()  # タグを削除
#      28 else:
#      29     # 属性を削除
#
# File /usr/local/lib/python3.8/site-packages/bs4/element.py:521, in PageElement.insert_before(self, *args)
#     519 parent = self.parent
#     520 if parent is None:
# --> 521     raise ValueError(
#     522         "Element has no parent, so 'before' has no meaning.")
#     523 if any(x is self for x in args):
#     524         raise ValueError("Can't insert an element before itself.")
#
# ValueError: Element has no parent, so 'before' has no meaning.

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
with open('data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl', 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 対象の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# 特定のタグを保持
allowed_tags = {'table', 'tr', 'td'}

# タグの属性を削除し、特定のタグ以外を削除
for elem in elements:
    for tag in elem.find_all():
        if tag.name not in allowed_tags:
            # タグの内容を保持して親タグに追加
            content = tag.decode_contents(formatter="html")
            parent = tag.parent
            new_soup = BeautifulSoup(content, 'html.parser')
            tag.decompose()  # タグを削除
            parent.append(new_soup)  # 親タグに内容を追加
        else:
            # 属性を削除
            tag.attrs = {}
            # 改行を除去
            if tag.name in {'tr', 'td'}:
                text = ''.join(str(c).replace('\n', '').replace(' ', '') for c in tag.contents)
                tag.clear()
                tag.append(text)

# 結果を出力
i = 0
for elem in elements:
    print(i)
    print('------------------------------------')
    print(elem)
    print('------------------------------------')
    i = i + 1
print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 29
#      27     new_soup = BeautifulSoup(content, 'html.parser')
#      28     tag.decompose()  # タグを削除
# ---> 29     parent.append(new_soup)  # 親タグに内容を追加
#      30 else:
#      31     # 属性を削除
#      32     tag.attrs = {}
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
with open('data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl', 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 対象の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# 特定のタグを保持
allowed_tags = {'table', 'tr', 'td'}

# タグの属性を削除し、特定のタグ以外を削除
for elem in elements:
    for tag in elem.find_all():
        if tag.name not in allowed_tags:
            # タグの内容を保持して親タグに追加
            tag.unwrap()
        else:
            # 属性を削除
            tag.attrs = {}
            # 改行を除去
            if tag.name in {'tr', 'td'}:
                new_contents = ''.join(str(content).replace('\n', '').replace(' ', '') for content in tag.contents)
                tag.clear()
                tag.append(new_contents)

# 結果を出力
i = 0
for elem in elements:
    print(i)
    print('------------------------------------')
    print(elem)
    print('------------------------------------')
    i = i + 1
print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 25
#      22 for tag in elem.find_all():
#      23     if tag.name not in allowed_tags:
#      24         # タグの内容を保持して親タグに追加
# ---> 25         tag.unwrap()
#      26     else:
#      27         # 属性を削除
#      28         tag.attrs = {}
#
# File /usr/local/lib/python3.8/site-packages/bs4/element.py:327, in PageElement.unwrap(self)
#     325 my_parent = self.parent
#     326 if self.parent is None:
# --> 327     raise ValueError(
#     328         "Cannot replace an element with its contents when that"
#     329         "element is not part of a tree.")
#     330 my_index = self.parent.index(self)
#     331 self.extract(_self_index=my_index)
#
# ValueError: Cannot replace an element with its contents when thatelement is not part of a tree.

# %% [markdown]
# #

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
with open('data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl', 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 対象の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# 特定のタグを保持
allowed_tags = {'table', 'tr', 'td'}

# タグの属性を削除し、特定のタグ以外を削除
for elem in elements:
    for tag in elem.find_all():
        if tag.name not in allowed_tags:
            # タグの内容を保持して親タグに追加
            content = ''.join(str(c) for c in tag.contents)
            parent = tag.parent
            tag.extract()  # タグをツリーから削除
            parent.append(BeautifulSoup(content, 'html.parser'))  # 親タグに内容を追加
        else:
            # 属性を削除
            tag.attrs = {}
            # 改行を除去
            if tag.name in {'tr', 'td'}:
                text = ''.join(str(c).replace('\n', '').replace(' ', '') for c in tag.contents)
                tag.clear()
                tag.append(text)

# 結果を出力
i = 0
for elem in elements:
    print(i)
    print('------------------------------------')
    print(elem)
    print('------------------------------------')
    i = i + 1
print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 28
#      26     parent = tag.parent
#      27     tag.extract()  # タグをツリーから削除
# ---> 28     parent.append(BeautifulSoup(content, 'html.parser'))  # 親タグに内容を追加
#      29 else:
#      30     # 属性を削除
#      31     tag.attrs = {}
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
with open('data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl', 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 対象の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# 特定のタグを保持
allowed_tags = {'table', 'tr', 'td'}

# タグの属性を削除し、特定のタグ以外を削除
for elem in elements:
    for tag in elem.find_all():
        if tag.name not in allowed_tags:
            parent = tag.parent
            if parent is not None:
                # タグの内容を保持して親タグに追加
                content = ''.join(str(c) for c in tag.contents)
                tag.extract()  # タグをツリーから削除
                new_soup = BeautifulSoup(content, 'html.parser')
                parent.append(new_soup)  # 親タグに内容を追加
        else:
            # 属性を削除
            tag.attrs = {}
            # 改行を除去
            if tag.name in {'tr', 'td'}:
                new_contents = ''.join(str(content).replace('\n', '').replace(' ', '') for content in tag.contents)
                tag.clear()
                tag.append(new_contents)

# 結果を出力
i = 0
for elem in elements:
    print(i)
    print('------------------------------------')
    print(elem)
    print('------------------------------------')
    i = i + 1
print(i)

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# テーブル内容の改行を削除し、タグと属性を削除する
def process_table_content(tag):
    # 改行を除去
    if tag.name in {'tr', 'td'}:
        new_contents = ''.join(str(content).replace('\n', '').replace(' ', '') for content in tag.contents)
        tag.clear()
        tag.append(new_contents)
    # タグと属性を削除
    tag.attrs = {}
    tag.unwrap()

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for elem in elements:
    for tag in elem.find_all():
        process_table_content(tag)

# 結果を出力
for i, elem in enumerate(elements):
    print(f"Element {i}:")
    print(elem.prettify())  # パースされた結果をきれいに表示する場合

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 33
#      31 for elem in elements:
#      32     for tag in elem.find_all():
# ---> 33         process_table_content(tag)
#      35 # 結果を出力
#      36 for i, elem in enumerate(elements):
#
# Cell In[17], line 25, in process_table_content(tag)
#      23 # タグと属性を削除
#      24 tag.attrs = {}
# ---> 25 tag.unwrap()
#
# File /usr/local/lib/python3.8/site-packages/bs4/element.py:327, in PageElement.unwrap(self)
#     325 my_parent = self.parent
#     326 if self.parent is None:
# --> 327     raise ValueError(
#     328         "Cannot replace an element with its contents when that"
#     329         "element is not part of a tree.")
#     330 my_index = self.parent.index(self)
#     331 self.extract(_self_index=my_index)
#
# ValueError: Cannot replace an element with its contents when thatelement is not part of a tree.

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# テーブル内容の改行を削除し、タグと属性を削除する
def process_table_content(tag):
    # 改行を除去
    if tag.name in {'tr', 'td'}:
        new_contents = ''.join(str(content).replace('\n', '').replace(' ', '') for content in tag.contents)
        tag.clear()
        tag.append(new_contents)
    # タグと属性を削除
    tag.attrs = {}
    if tag.parent:
        tag.unwrap()

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for elem in elements:
    for tag in elem.find_all():
        process_table_content(tag)

# 結果を出力
for i, elem in enumerate(elements):
    print(f"Element {i}:")
    print(elem.prettify())  # パースされた結果をきれいに表示する場合

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# テーブル内容の改行と属性を削除する
def process_table_content(tag):
    # 改行を除去
    if tag.name in {'tr', 'td'}:
        new_contents = ''.join(str(content).replace('\n', '').replace(' ', '') for content in tag.contents)
        tag.clear()
        tag.append(new_contents)
    # 属性を削除
    tag.attrs = {}

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for elem in elements:
    for tag in elem.find_all():
        process_table_content(tag)

# 結果を出力
for i, elem in enumerate(elements):
    print(f"Element {i}:")
    print(elem.prettify())  # パースされた結果をきれいに表示する場合

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# td タグの内容を修正してエスケープ文字を元の文字に戻す
def process_td_content(td_tag):
    for p_tag in td_tag.find_all('pstyle'):
        p_tag.name = 'p'
        del p_tag['style']

# td, tr 以外の全てのタグを削除する
def remove_unwanted_tags(tag):
    if tag.name not in {'td', 'tr'}:
        tag.decompose()

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for elem in elements:
    for tag in elem.find_all():
        if tag.name == 'td':
            process_td_content(tag)
        else:
            remove_unwanted_tags(tag)

# 結果を出力
for i, elem in enumerate(elements):
    print(f"Element {i}:")
    print(elem.prettify())  # パースされた結果をきれいに表示する場合

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# Element 0:
# <jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock contextRef="FilingDateInstant">
# </jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock>

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# td タグの内容を修正してエスケープ文字を元の文字に戻す
def process_td_content(td_tag):
    for p_tag in td_tag.find_all('pstyle'):
        p_tag.name = 'p'
        del p_tag['style']

# td, tr 以外の全てのタグを削除する
def remove_unwanted_tags(tag):
    if tag.name not in {'td', 'tr'}:
        tag.decompose()

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for elem in elements:
    for tag in elem.find_all():
        if tag.name == 'td':
            process_td_content(tag)
        else:
            # td, tr 以外のタグを削除する
            remove_unwanted_tags(tag)

# 結果を出力
for i, elem in enumerate(elements):
    print(f"Element {i}:")
    # タグとテキストを含む内容を出力
    print(elem)

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# td タグの内容を修正してエスケープ文字を元の文字に戻す
def process_td_content(td_tag):
    for p_tag in td_tag.find_all('pstyle'):
        p_tag.name = 'p'
        del p_tag['style']

# td, tr 以外の全てのタグを削除する
def remove_unwanted_tags(tag):
    if tag.name not in {'td', 'tr'}:
        tag.decompose()

# テキストコンテンツを保持しつつタグと属性を整形する
def process_element(elem):
    for tag in elem.find_all():
        if tag.name == 'td':
            process_td_content(tag)
        else:
            remove_unwanted_tags(tag)

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for elem in elements:
    process_element(elem)

# 結果を出力
for i, elem in enumerate(elements):
    print(f"Element {i}:")
    # タグとテキストを含む内容を出力
    print(elem.prettify())  # パースされた結果をきれいに表示する場合

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# Element 0:
# <jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock contextRef="FilingDateInstant">
# </jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock>

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

head(decoded_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# td タグの内容を修正してエスケープ文字を元の文字に戻す
def process_td_content(td_tag):
    for p_tag in td_tag.find_all('pstyle'):
        p_tag.name = 'p'
        del p_tag['style']

# td, tr 以外の全てのタグを削除する
def remove_unwanted_tags(tag):
    if tag.name not in {'td', 'tr'}:
        tag.decompose()

# テキストコンテンツを保持しつつタグと属性を整形する
def process_element(elem):
    for tag in elem.find_all():
        if tag.name == 'td':
            process_td_content(tag)
        else:
            remove_unwanted_tags(tag)

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for elem in elements:
    process_element(elem)

# 結果を出力
for i, elem in enumerate(elements):
    print(f"Element {i}:")
    # タグとテキストを含む内容を出力
    for content in elem.contents:
        if isinstance(content, str):
            print(content)
        else:
            print(content.prettify())

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 13
#      10 # エスケープ文字を元のタグに戻す
#      11 decoded_content = html.unescape(xbrl_content)
# ---> 13 head(decoded_content)
#      15 # BeautifulSoupでパース
#      16 soup = BeautifulSoup(decoded_content, 'xml')
#
# NameError: name 'head' is not defined

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# td タグの内容を修正してエスケープ文字を元の文字に戻す
def process_td_content(td_tag):
    for p_tag in td_tag.find_all('pstyle'):
        p_tag.name = 'p'
        del p_tag['style']

# td, tr 以外の全てのタグを削除する
def remove_unwanted_tags(tag):
    if tag.name not in {'td', 'tr'}:
        tag.decompose()

# テキストコンテンツを保持しつつタグと属性を整形する
def process_element(elem):
    for tag in elem.find_all():
        if tag.name == 'td':
            process_td_content(tag)
        else:
            remove_unwanted_tags(tag)

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for elem in elements:
    process_element(elem)

# 結果を出力
for i, elem in enumerate(elements):
    print(f"Element {i}:")
    # タグとテキストを含む内容を出力
    for content in elem.contents:
        if isinstance(content, str):
            print(content)
        else:
            print(content.prettify())

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# td タグの内容を修正してエスケープ文字を元の文字に戻す
def process_td_content(td_tag):
    for p_tag in td_tag.find_all('pstyle'):
        p_tag.name = 'p'
        del p_tag['style']

# td, tr 以外の全てのタグを削除する
def remove_unwanted_tags(tag):
    if tag.name not in {'td', 'tr'}:
        tag.decompose()

# テキストコンテンツを保持しつつタグと属性を整形する
def process_element(elem):
    for tag in elem.find_all():
        if tag.name == 'td':
            process_td_content(tag)
        else:
            remove_unwanted_tags(tag)

    # 各要素の内容をテキストとして取得して出力
    element_text = elem.get_text(separator="\n", strip=True)
    print(element_text)

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    print(f"Element {i}:")
    process_element(elem)
    print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# Element 0:
#
# ----------------------------------

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# td タグの内容を修正してエスケープ文字を元の文字に戻す
def process_td_content(td_tag):
    for p_tag in td_tag.find_all('pstyle'):
        p_tag.name = 'p'
        del p_tag['style']

# td, tr 以外の全てのタグを削除する
def remove_unwanted_tags(tag):
    if tag.name not in {'td', 'tr'}:
        tag.decompose()

# テキストコンテンツを保持しつつタグと属性を整形する
def process_element(elem):
    for tag in elem.find_all():
        if tag.name == 'td':
            process_td_content(tag)
        else:
            remove_unwanted_tags(tag)

    # 各要素の内容をテキストとして取得して出力
    element_text = elem.get_text(separator="\n", strip=True)
    return element_text

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    print(f"Element {i}:")
    processed_text = process_element(elem)
    print(processed_text)
    print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# Element 0:
#
# ----------------------------------

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# td タグの内容を修正してエスケープ文字を元の文字に戻す
def process_td_content(td_tag):
    for p_tag in td_tag.find_all('pstyle'):
        p_tag.name = 'p'
        del p_tag['style']

# td, tr 以外の全てのタグを削除する
def remove_unwanted_tags(tag):
    if tag.name not in {'td', 'tr'}:
        tag.decompose()

# テキストコンテンツを保持しつつタグと属性を整形する
def process_element(elem):
    for tag in elem.find_all():
        if tag.name == 'td':
            process_td_content(tag)
        else:
            remove_unwanted_tags(tag)

    # 各要素の内容をテキストとして取得して出力
    element_text = elem.get_text(separator="\n", strip=True)
    return element_text

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    print(f"Element {i}:")
    processed_text = process_element(elem)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(processed_text)
    print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# Element 0:
# ----------------------------------

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'td' or tag.name == 'tr':
        for child in tag.children:
            if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                child.name = 'p'
                del child['style']
        # テキストノードの改行を除去
        tag.string = tag.get_text(separator="", strip=True)

# すべてのタグを削除し、テキストのみを残す
def remove_all_tags(tag):
    tag.unwrap()

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、テキストのみを残す
    tag.unwrap()

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    print(f"Element {i}:")
    print(processed_text)
    print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 49
#      46     remove_newlines_within_tags(tag)
#      48 # すべてのタグを削除し、テキストのみを残す
# ---> 49 tag.unwrap()
#      51 # 処理後のテキストを出力する
#      52 processed_text = elem.get_text(separator="\n", strip=True)
#
# File /usr/local/lib/python3.8/site-packages/bs4/element.py:327, in PageElement.unwrap(self)
#     325 my_parent = self.parent
#     326 if self.parent is None:
# --> 327     raise ValueError(
#     328         "Cannot replace an element with its contents when that"
#     329         "element is not part of a tree.")
#     330 my_index = self.parent.index(self)
#     331 self.extract(_self_index=my_index)
#
# ValueError: Cannot replace an element with its contents when thatelement is not part of a tree.

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'td' or tag.name == 'tr':
        for child in tag.children:
            if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                child.name = 'p'
                del child['style']
        # テキストノードの改行を除去
        tag.string = tag.get_text(separator="", strip=True)

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    for content in tag.contents:
        tag.parent.insert_before(content)
    tag.decompose()

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    print(f"Element {i}:")
    print(processed_text)
    print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# Element 0:
#
# ----------------------------------

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'td' or tag.name == 'tr':
        for child in tag.children:
            if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                child.name = 'p'
                del child['style']
        # テキストノードの改行を除去
        tag.string = tag.get_text(separator="", strip=True)

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    for content in tag.contents:
        tag.parent.insert_before(content)
    tag.decompose()

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'td' or tag.name == 'tr':
        for child in tag.children:
            if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                child.name = 'p'
                del child['style']
        # テキストノードの改行を除去
        tag.string = tag.get_text(separator="", strip=True)

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    tag.unwrap()

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'td' or tag.name == 'tr':
        for child in tag.children:
            if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                child.name = 'p'
                del child['style']
        # テキストノードの改行を除去
        tag.string = tag.get_text(separator="", strip=True)

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    print("Before removing tags:")
    print(tag.prettify())

    tag.unwrap()

    print("\nAfter removing tags:")
    print(tag.prettify())

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"\nProcessed Text for Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'td' or tag.name == 'tr':
        for child in tag.children:
            if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                child.name = 'p'
                del child['style']
        # テキストノードの改行を除去
        tag.string = tag.get_text(separator="", strip=True)

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    contents = tag.contents
    tag.clear()
    tag.append(contents)

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"\nProcessed Text for Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 51
#      48     remove_newlines_within_tags(tag)
#      50 # すべてのタグを削除し、コンテンツのみを残す
# ---> 51 remove_all_tags(elem)
#      53 # 処理後のテキストを出力する
#      54 processed_text = elem.get_text(separator="\n", strip=True)
#
# Cell In[42], line 35, in remove_all_tags(tag)
#      33 contents = tag.contents
#      34 tag.clear()
# ---> 35 tag.append(contents)
#
# File /usr/local/lib/python3.8/site-packages/bs4/element.py:493, in PageElement.append(self, tag)
#     488 def append(self, tag):
#     489     """Appends the given PageElement to the contents of this one.
#     490
#     491     :param tag: A PageElement.
#     492     """
# --> 493     self.insert(len(self.contents), tag)
#
# File /usr/local/lib/python3.8/site-packages/bs4/element.py:445, in PageElement.insert(self, position, new_child)
# ...

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'td' or tag.name == 'tr':
        for child in tag.children:
            if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                child.name = 'p'
                del child['style']
        # テキストノードの改行を除去
        tag.string = tag.get_text(separator="", strip=True)

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    contents = tag.contents
    tag.clear()
    for content in contents:
        tag.append(content)

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"\nProcessed Text for Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name in ['td', 'tr']:
        for child in tag.find_all(['p', 'pstyle'], recursive=False):
            if child.name == 'pstyle':
                child.name = 'p'
                del child['style']
            child.string = child.get_text(separator="", strip=True)

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    contents = tag.contents
    tag.clear()
    for content in contents:
        tag.append(content)

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"\nProcessed Text for Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'td' or tag.name == 'tr':
        text = tag.get_text(separator="", strip=True)
        tag.string = text

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    for child in tag.find_all(recursive=False):
        remove_all_tags(child)
        child.unwrap()

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    print(f"Element {i} before processing:")
    print(elem.prettify())

    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    print(f"Element {i} after removing attributes and newlines:")
    print(elem.prettify())
    
    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    print(f"Element {i} after removing all tags:")
    print(elem.prettify())

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"\nProcessed Text for Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# Element 0 before processing:
# <jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock contextRef="FilingDateInstant">
#  <h3>
#   ２ 【サステナビリティに関する考え方及び取組】
#  </h3>
#  <p style="margin-left: 24px; text-align: justify; text-justify: inter-ideograph">
#   <span style="font-size: 14px">
#    (1)サステナビリティ全般
#   </span>
#  </p>
#  <p style="margin-left: 36px; text-align: justify; text-justify: inter-ideograph; text-indent: 1.8px">
#   <span style="font-size: 14px">
#    ①ガバナンス
#   </span>
#  </p>
#  <p style="margin-left: 46.666666666666666666666666667px; text-align: justify; text-justify: inter-ideograph; text-indent: 1.8px">
#   ア．サステナビリティの考え方
#  </p>
#  <p style="margin-left: 46.666666666666666666666666667px; text-align: justify; text-justify: inter-ideograph; text-indent: 12px">
# ...

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'td' or tag.name == 'tr':
        for child in tag.children:
            if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                child.name = 'p'
                del child['style']
        # テキストノードの改行を除去
        tag.string = tag.get_text(separator="", strip=True)

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    print("Before removing tags:")
    print(tag.prettify())

    tag.unwrap()

    print("\nAfter removing tags:")
    print(tag.prettify())

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"\nProcessed Text for Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'tr':
        for td_tag in tag.find_all('td'):
            for child in td_tag.children:
                if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                    child.name = 'p'
                    del child['style']
            # テキストノードの改行を除去
            td_tag.string = td_tag.get_text(separator="", strip=True)

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    print("Before removing tags:")
    print(tag.prettify())

    # タグを削除せずに中身を置き換える
    tag.string = tag.get_text(separator="", strip=True)

    print("\nAfter removing tags:")
    print(tag.prettify())

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tr_tag in elem.find_all('tr'):
        remove_newlines_within_tags(tr_tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"\nProcessed Text for Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'td' or tag.name == 'tr':
        for child in tag.children:
            if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                child.name = 'p'
                del child['style']
        # テキストノードの改行を除去
        tag.string = '\n'.join(child.get_text(separator="", strip=True) for child in tag.contents if isinstance(child, BeautifulSoup))

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    print("Before removing tags:")
    print(tag.prettify())

    # コンテンツごとに改行を挿入してタグを削除
    content_text = '\n'.join(child.get_text(separator="", strip=True) for child in tag.contents if isinstance(child, BeautifulSoup))
    tag.string = content_text

    print("\nAfter removing tags:")
    print(tag.prettify())

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"\nProcessed Text for Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# Before removing tags:
# <jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock contextRef="FilingDateInstant">
#  <h3>
#   ２ 【サステナビリティに関する考え方及び取組】
#  </h3>
#  <p>
#   <span>
#    (1)サステナビリティ全般
#   </span>
#  </p>
#  <p>
#   <span>
#    ①ガバナンス
#   </span>
#  </p>
#  <p>
#   ア．サステナビリティの考え方
#  </p>
#  <p>
#   三菱電機グループは、「企業理念」「私たちの価値観」「コミットメント」に則り、全ての活動においてサステナビリティを志向した取組みを行います。また、「『事業を通じた社会課題の解決』という原点に立ち、サステナビリティの実現を経営の根幹に位置づける。これにより、企業価値の持続的向上を図り、社会・顧客・株主・従業員をはじめとしたステークホルダーへの責任を果たす」ことを経営方針に掲げています。社会からの期待や要請・意見を活動に反映させ、社会や環境に与えるネガティブな影響を最小化し、持続可能な社会の実現に向けた取組みを推進します。
#  </p>
#  <p>
#  </p>
#  <p>
#   イ．サステナビリティの実現に向けた推進事項
#  </p>
#  <p>
#   サステナビリティの実現に向け、以下の4点を推進事項としています。
#  </p>
#  <div>
#   <table>
#    <colgroup>
#     <col/>
#     <col/>
#    </colgroup>
#    <tbody>
#     <tr>
#     </tr>
#     <tr>
#     </tr>
#     <tr>
#     </tr>
#     <tr>
#     </tr>
#    </tbody>
#   </table>
#  </div>
#  <p>
#  </p>
#  <p>
#   ウ．サステナビリティ推進体制
#  </p>
# ...

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'td' or tag.name == 'tr':
        for child in tag.children:
            if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                child.name = 'p'
                del child['style']
        # テキストノードの改行を除去
        tag.string = '\n'.join(child.get_text(separator="", strip=True) for child in tag.contents if isinstance(child, BeautifulSoup))

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    print("Before removing tags:")
    print(tag.prettify())

    # コンテンツごとに改行を挿入してタグを削除
    content_text = ''.join(str(child) for child in tag.contents if isinstance(child, BeautifulSoup))

    # 最後にコンテンツを設定
    tag.contents = [BeautifulSoup(content_text, 'html.parser')]

    print("\nAfter removing tags:")
    print(tag.prettify())

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"\nProcessed Text for Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# Before removing tags:
# <jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock contextRef="FilingDateInstant">
#  <h3>
#   ２ 【サステナビリティに関する考え方及び取組】
#  </h3>
#  <p>
#   <span>
#    (1)サステナビリティ全般
#   </span>
#  </p>
#  <p>
#   <span>
#    ①ガバナンス
#   </span>
#  </p>
#  <p>
#   ア．サステナビリティの考え方
#  </p>
#  <p>
#   三菱電機グループは、「企業理念」「私たちの価値観」「コミットメント」に則り、全ての活動においてサステナビリティを志向した取組みを行います。また、「『事業を通じた社会課題の解決』という原点に立ち、サステナビリティの実現を経営の根幹に位置づける。これにより、企業価値の持続的向上を図り、社会・顧客・株主・従業員をはじめとしたステークホルダーへの責任を果たす」ことを経営方針に掲げています。社会からの期待や要請・意見を活動に反映させ、社会や環境に与えるネガティブな影響を最小化し、持続可能な社会の実現に向けた取組みを推進します。
#  </p>
#  <p>
#  </p>
#  <p>
#   イ．サステナビリティの実現に向けた推進事項
#  </p>
#  <p>
#   サステナビリティの実現に向け、以下の4点を推進事項としています。
#  </p>
#  <div>
#   <table>
#    <colgroup>
#     <col/>
#     <col/>
#    </colgroup>
#    <tbody>
#     <tr>
#     </tr>
#     <tr>
#     </tr>
#     <tr>
#     </tr>
#     <tr>
#     </tr>
#    </tbody>
#   </table>
#  </div>
#  <p>
#  </p>
#  <p>
#   ウ．サステナビリティ推進体制
#  </p>
# ...

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'td' or tag.name == 'tr':
        for child in tag.children:
            if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                child.name = 'p'
                del child['style']
        # テキストノードの改行を除去
        tag.string = '\n'.join(child.get_text(separator="", strip=True) for child in tag.contents if isinstance(child, BeautifulSoup))

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    print("Before removing tags:")
    print(tag.prettify())

    # コンテンツごとに改行を挿入してタグを削除
    content_text = ''.join(str(child) for child in tag.contents if isinstance(child, BeautifulSoup))

    # 元のタグに内容を設定する
    tag.clear()
    tag.append(BeautifulSoup(content_text, 'html.parser'))

    print("\nAfter removing tags:")
    print(tag.prettify())

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"\nProcessed Text for Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# Before removing tags:
# <jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock contextRef="FilingDateInstant">
#  <h3>
#   ２ 【サステナビリティに関する考え方及び取組】
#  </h3>
#  <p>
#   <span>
#    (1)サステナビリティ全般
#   </span>
#  </p>
#  <p>
#   <span>
#    ①ガバナンス
#   </span>
#  </p>
#  <p>
#   ア．サステナビリティの考え方
#  </p>
#  <p>
#   三菱電機グループは、「企業理念」「私たちの価値観」「コミットメント」に則り、全ての活動においてサステナビリティを志向した取組みを行います。また、「『事業を通じた社会課題の解決』という原点に立ち、サステナビリティの実現を経営の根幹に位置づける。これにより、企業価値の持続的向上を図り、社会・顧客・株主・従業員をはじめとしたステークホルダーへの責任を果たす」ことを経営方針に掲げています。社会からの期待や要請・意見を活動に反映させ、社会や環境に与えるネガティブな影響を最小化し、持続可能な社会の実現に向けた取組みを推進します。
#  </p>
#  <p>
#  </p>
#  <p>
#   イ．サステナビリティの実現に向けた推進事項
#  </p>
#  <p>
#   サステナビリティの実現に向け、以下の4点を推進事項としています。
#  </p>
#  <div>
#   <table>
#    <colgroup>
#     <col/>
#     <col/>
#    </colgroup>
#    <tbody>
#     <tr>
#     </tr>
#     <tr>
#     </tr>
#     <tr>
#     </tr>
#     <tr>
#     </tr>
#    </tbody>
#   </table>
#  </div>
#  <p>
#  </p>
#  <p>
#   ウ．サステナビリティ推進体制
#  </p>
# ...

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'tr':
        for td_tag in tag.find_all('td'):
            for child in td_tag.children:
                if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                    child.name = 'p'
                    del child['style']
            # テキストノードの改行を除去
            td_tag.string = td_tag.get_text(separator="", strip=True)

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    print("Before removing tags:")
    print(tag.prettify())

    # コンテンツごとに改行を挿入してタグを削除
    content_text = ''.join(str(child) for child in tag.contents if isinstance(child, BeautifulSoup))

    # タグを削除する
    tag.extract()

    print("\nAfter removing tags:")
    print(content_text)

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"\nProcessed Text for Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# Before removing tags:
# <jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock contextRef="FilingDateInstant">
#  <h3>
#   ２ 【サステナビリティに関する考え方及び取組】
#  </h3>
#  <p>
#   <span>
#    (1)サステナビリティ全般
#   </span>
#  </p>
#  <p>
#   <span>
#    ①ガバナンス
#   </span>
#  </p>
#  <p>
#   ア．サステナビリティの考え方
#  </p>
#  <p>
#   三菱電機グループは、「企業理念」「私たちの価値観」「コミットメント」に則り、全ての活動においてサステナビリティを志向した取組みを行います。また、「『事業を通じた社会課題の解決』という原点に立ち、サステナビリティの実現を経営の根幹に位置づける。これにより、企業価値の持続的向上を図り、社会・顧客・株主・従業員をはじめとしたステークホルダーへの責任を果たす」ことを経営方針に掲げています。社会からの期待や要請・意見を活動に反映させ、社会や環境に与えるネガティブな影響を最小化し、持続可能な社会の実現に向けた取組みを推進します。
#  </p>
#  <p>
#  </p>
#  <p>
#   イ．サステナビリティの実現に向けた推進事項
#  </p>
#  <p>
#   サステナビリティの実現に向け、以下の4点を推進事項としています。
#  </p>
#  <div>
#   <table>
#    <colgroup>
#     <col/>
#     <col/>
#    </colgroup>
#    <tbody>
#     <tr>
#      <td>
#       持続可能な社会に事業で貢献
#      </td>
#      <td>
#       事業を通じて社会課題や環境課題を解決し、「活力とゆとりある社会の実現」に貢献すること。
#      </td>
#     </tr>
#     <tr>
#      <td>
# ...

# %%
from bs4 import BeautifulSoup
import html

# XBRLファイルを読み込む
file_path = 'data/XBRL/jpcrp030000-asr-001_E01739-000_2023-03-31_01_2023-06-29.xbrl'

with open(file_path, 'r', encoding='utf-8') as file:
    xbrl_content = file.read()

# エスケープ文字を元のタグに戻す
decoded_content = html.unescape(xbrl_content)

# BeautifulSoupでパース
soup = BeautifulSoup(decoded_content, 'xml')

# 各タグの属性情報を削除する
def remove_tag_attributes(tag):
    for attribute in list(tag.attrs):
        del tag[attribute]

# <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
def remove_newlines_within_tags(tag):
    if tag.name == 'tr':
        for td_tag in tag.find_all('td'):
            for child in td_tag.children:
                if child.name == 'pstyle':  # <pstyle>タグは<p>に変換してスタイル属性を削除
                    child.name = 'p'
                    del child['style']
            # テキストノードの改行を除去
            td_tag.string = '\n'.join(child.get_text(separator="", strip=True) for child in td_tag.contents if isinstance(child, BeautifulSoup))

# すべてのタグを削除し、コンテンツのみを残す
def remove_all_tags(tag):
    content_text = ''.join(str(child) for child in tag.contents if isinstance(child, BeautifulSoup))
    tag.extract()  # タグを削除する
    return content_text

# 特定の要素を見つける
elements = soup.find_all('jpcrp030000-asr_E01739-000:DisclosureOfSustainabilityRelatedFinancialInformationTextBlock')

# テーブル内容の各要素に対して処理を適用
for i, elem in enumerate(elements):
    # 各タグの属性情報を削除する
    for tag in elem.find_all():
        remove_tag_attributes(tag)
    
    # <tr>タグ、<td>タグで囲まれたテキストから改行コードを除去する
    for tag in elem.find_all(['tr', 'td']):
        remove_newlines_within_tags(tag)

    # すべてのタグを削除し、コンテンツのみを残す
    content_text = remove_all_tags(elem)

    # 処理後のテキストを出力する
    processed_text = elem.get_text(separator="\n", strip=True)
    if processed_text.strip():  # テキストが空でない場合のみ出力する
        print(f"\nProcessed Text for Element {i}:")
        print(processed_text)
        print("----------------------------------")

# 必要に応じて、修正されたXMLをファイルに保存する場合
# with open('processed_xbrl.xml', 'w', encoding='utf-8') as output_file:
#     output_file.write(soup.prettify())
# Out:
# Processed Text for Element 0:
# ２ 【サステナビリティに関する考え方及び取組】
# (1)サステナビリティ全般
# ①ガバナンス
# ア．サステナビリティの考え方
# 三菱電機グループは、「企業理念」「私たちの価値観」「コミットメント」に則り、全ての活動においてサステナビリティを志向した取組みを行います。また、「『事業を通じた社会課題の解決』という原点に立ち、サステナビリティの実現を経営の根幹に位置づける。これにより、企業価値の持続的向上を図り、社会・顧客・株主・従業員をはじめとしたステークホルダーへの責任を果たす」ことを経営方針に掲げています。社会からの期待や要請・意見を活動に反映させ、社会や環境に与えるネガティブな影響を最小化し、持続可能な社会の実現に向けた取組みを推進します。
# イ．サステナビリティの実現に向けた推進事項
# サステナビリティの実現に向け、以下の4点を推進事項としています。
# ウ．サステナビリティ推進体制
# 三菱電機グループのサステナビリティの取組みは、三菱電機の執行役会議から委嘱を受け、経営企画及びサステナビリティを担当する執行役(CSO:Chief Strategy Officer)が委員長を務めるサステナビリティ委員会で方針・計画を決定しています。サステナビリティ委員会は三菱電機のコーポレート部門長や事業戦略担当部門長(経営企画室や人事部などの環境、社会、ガバナンス、事業戦略担当の34名[2023年4月1日時点])で構成されており、マテリアリティ（重要課題）に基づく活動実績の把握や活動計画の決定、法改正への対応など、三菱電機グループの横断的な視点から議論を行い、取組みを推進しています。また、倫理・遵法、品質の確保・向上、環境保全活動、社会貢献活動、ステークホルダーの皆様とのコミュニケーションなどの具体的な取組みについては、担当部門が責任を持って推進しています。
# サステナビリティ委員会の事務局はサステナビリティ推進部が担当しています。三菱電機グループのサステナビリティの取組みを更に推進するため、2023年度から、サステナビリティ推進部を社長直轄組織としました。
# ...
